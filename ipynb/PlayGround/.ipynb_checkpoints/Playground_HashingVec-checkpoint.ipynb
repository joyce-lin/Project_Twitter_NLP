# %%
import requests
import numpy as np
import pandas as pd
import json
from IPython.display import display
import re
import os,sys,inspect
currentdir = os.path.dirname(os.path.abspath(inspect.getfile(inspect.currentframe())))
parentdir = os.path.dirname(currentdir)
sys.path.insert(0,parentdir)

from lib.twitter_keys import keys

# %%
sql_select = '''
select * from tweets where lang = 'en'
'''

# %%
import psycopg2 as pg2
import psycopg2.extras as pgex
this_host='54.69.228.16'
this_user='postgres'
this_password='postgres'
conn = pg2.connect(host = this_host, 
                        user = this_user,
                        password = this_password)
cur = conn.cursor(cursor_factory=pgex.RealDictCursor)
#cur.execute(sql_create)
#cur.execute(sql_drop)
#cur.execute(sql_insert)
#conn.commit()
cur.execute(sql_select)
rows = cur.fetchall()
conn.close()
df = pd.DataFrame(rows)

# %%
len(df)
# Out:
# 52496

# %%
df.tail(100)
# Out:
#     cleaned_tweet        country                      created_at entities  \
# 900          None  United States  Tue May 30 04:38:56 +0000 2017     None
# 901          None  United States  Tue May 30 04:38:56 +0000 2017     None
# 902          None  United States  Tue May 30 04:38:57 +0000 2017     None
# 903          None  United States  Tue May 30 04:38:59 +0000 2017     None
# 904          None  United States  Tue May 30 04:38:59 +0000 2017     None
# 905          None  United States  Tue May 30 04:39:00 +0000 2017     None
# 906          None  United States  Tue May 30 04:39:01 +0000 2017     None
# 907          None  United States  Tue May 30 04:39:02 +0000 2017     None
# 908          None  United States  Tue May 30 04:39:03 +0000 2017     None
# 909          None  United States  Tue May 30 04:39:04 +0000 2017     None
# 910          None  United States  Tue May 30 04:39:04 +0000 2017     None
# 911          None  United States  Tue May 30 04:39:04 +0000 2017     None
# 912          None  United States  Tue May 30 04:39:04 +0000 2017     None
# 913          None  United States  Tue May 30 04:39:21 +0000 2017     None
# 914          None  United States  Tue May 30 04:39:04 +0000 2017     None
# 915          None  United States  Tue May 30 04:39:05 +0000 2017     None
# 916          None  United States  Tue May 30 04:39:06 +0000 2017     None
# 917          None  United States  Tue May 30 04:39:07 +0000 2017     None
# 918          None  United States  Tue May 30 04:39:07 +0000 2017     None
# 919          None  United States  Tue May 30 04:39:08 +0000 2017     None
# 920          None  United States  Tue May 30 04:39:08 +0000 2017     None
# 921          None  United States  Tue May 30 04:39:08 +0000 2017     None
# 922          None  United States  Tue May 30 04:39:09 +0000 2017     None
# 923          None  United States  Tue May 30 04:39:09 +0000 2017     None
# 924          None  United States  Tue May 30 04:39:10 +0000 2017     None
# 925          None  United States  Tue May 30 04:39:13 +0000 2017     None
# 926          None  United States  Tue May 30 04:39:14 +0000 2017     None
# 927          None  United States  Tue May 30 04:39:15 +0000 2017     None
# 928          None  United States  Tue May 30 04:39:15 +0000 2017     None
# 929          None  United States  Tue May 30 04:39:16 +0000 2017     None
# ..            ...            ...                             ...      ...
# 970          None  United States  Tue May 30 04:39:46 +0000 2017     None
# 971          None  United States  Tue May 30 04:39:46 +0000 2017     None
# 972          None  United States  Tue May 30 04:39:47 +0000 2017     None
# 973          None  United States  Tue May 30 04:39:47 +0000 2017     None
# 974          None  United States  Tue May 30 04:39:48 +0000 2017     None
# 975          None  United States  Tue May 30 04:39:48 +0000 2017     None
# 976          None  United States  Tue May 30 04:39:49 +0000 2017     None
# 977          None  United States  Tue May 30 04:39:50 +0000 2017     None
# 978          None  United States  Tue May 30 04:39:50 +0000 2017     None
# 979          None  United States  Tue May 30 04:39:50 +0000 2017     None
# 980          None  United States  Tue May 30 04:39:50 +0000 2017     None
# 981          None  United States  Tue May 30 04:39:51 +0000 2017     None
# 982          None  United States  Tue May 30 04:39:52 +0000 2017     None
# 983          None  United States  Tue May 30 04:39:52 +0000 2017     None
# 984          None  United States  Tue May 30 04:39:52 +0000 2017     None
# 985          None  United States  Tue May 30 04:39:53 +0000 2017     None
# 986          None  United States  Tue May 30 04:39:53 +0000 2017     None
# 987          None  United States  Tue May 30 04:39:54 +0000 2017     None
# 988          None  United States  Tue May 30 04:39:54 +0000 2017     None
# 989          None  United States  Tue May 30 04:39:56 +0000 2017     None
# 990          None  United States  Tue May 30 04:39:56 +0000 2017     None
# 991          None  United States  Tue May 30 04:39:56 +0000 2017     None
# 992          None  United States  Tue May 30 04:39:56 +0000 2017     None
# 993          None  United States  Tue May 30 04:39:58 +0000 2017     None
# 994          None  United States  Tue May 30 04:39:58 +0000 2017     None
# 995          None  United States  Tue May 30 04:39:57 +0000 2017     None
# 996          None  United States  Tue May 30 04:39:59 +0000 2017     None
# 997          None  United States  Tue May 30 04:40:00 +0000 2017     None
# 998          None  United States  Tue May 30 04:40:01 +0000 2017     None
# 999          None  United States  Tue May 30 04:40:01 +0000 2017     None
#
#       geo geo_enabled hashtags                  id lang   latitude  \
# 900  None        None     None  869412788673814528   en   0.000000
# 901  None        None     None  869412790456406016   en   0.000000
# 902  None        None     None  869412792352342016   en   0.000000
# 903  None        None     None  869412799683768320   en   0.000000
# 904  None        None     None  869412803206971392   en   0.000000
# 905  None        None     None  869412806722027520   en   0.000000
# 906  None        None     None  869412809007808512   en   0.000000
# 907  None        None     None  869412813873098752   en   0.000000
# 908  None        None     None  869412817476177920   en   0.000000
# 909  None        None     None  869412821515161604   en   0.000000
# 910  None        None     None  869412822081388544   en   0.000000
# 911  None        None     None  869412823213854720   en   0.000000
# 912  None        None     None  869412823864008704   en   0.000000
# 913  None        None     None  869412895255179264   en   0.000000
# 914  None        None     None  869412823344046081   en  34.164280
# 915  None        None     None  869412827957788673   en   0.000000
# 916  None        None     None  869412831074156545   en   0.000000
# 917  None        None     None  869412834924306432   en   0.000000
# 918  None        None     None  869412835821993988   en   0.000000
# 919  None        None     None  869412837793435648   en  32.783300
# 920  None        None     None  869412839424802816   en   0.000000
# 921  None        None     None  869412840020484096   en   0.000000
# 922  None        None     None  869412842595913728   en   0.000000
# 923  None        None     None  869412842889396224   en   0.000000
# 924  None        None     None  869412847972954112   en   0.000000
# 925  None        None     None  869412860081852417   en   0.000000
# 926  None        None     None  869412866440523776   en   0.000000
# 927  None        None     None  869412867631611904   en   0.000000
# 928  None        None     None  869412869254893569   en   0.000000
# 929  None        None     None  869412873512013826   en   0.000000
# ..    ...         ...      ...                 ...  ...        ...
# 970  None        None     None  869412999207014400   en   0.000000
# 971  None        None     None  869412999693578240   en  37.775000
# 972  None        None     None  869413002042200064   en   0.000000
# 973  None        None     None  869413003615059969   en   0.000000
# 974  None        None     None  869413008627445760   en  37.660838
# 975  None        None     None  869413008614850564   en   0.000000
# 976  None        None     None  869413010980425729   en  32.825227
# 977  None        None     None  869413015514300416   en   0.000000
# 978  None        None     None  869413015594180608   en   0.000000
# 979  None        None     None  869413016789409792   en   0.000000
# 980  None        None     None  869413017104007169   en   0.000000
# 981  None        None     None  869413021759586304   en   0.000000
# 982  None        None     None  869413023651377153   en   0.000000
# 983  None        None     None  869413024016326656   en   0.000000
# 984  None        None     None  869413025190752257   en  34.050822
# 985  None        None     None  869413027132694528   en   0.000000
# 986  None        None     None  869413028361510912   en   0.000000
# 987  None        None     None  869413031863869440   en   0.000000
# 988  None        None     None  869413032174133248   en   0.000000
# 989  None        None     None  869413039832932352   en   0.000000
# 990  None        None     None  869413040524976128   en   0.000000
# 991  None        None     None  869413041854664705   en  34.083360
# 992  None        None     None  869413042139746304   en   0.000000
# 993  None        None     None  869413047533686784   en   0.000000
# 994  None        None     None  869413047835779072   en   0.000000
# 995  None        None     None  869413045549715457   en   0.000000
# 996  None        None     None  869413051841339392   en   0.000000
# 997  None        None     None  869413055867658240   en   0.000000
# 998  None        None     None  869413059881820165   en   0.000000
# 999  None        None     None  869413061160914946   en   0.000000
#
#                       location   longitude    place_type regin  retweet_count  \
# 900            Los Angeles, CA    0.000000          city  None              0
# 901            Los Angeles, CA    0.000000          city  None              0
# 902                 Dallas, TX    0.000000          city  None              0
# 903          San Francisco, CA    0.000000          city  None              0
# 904            Los Angeles, CA    0.000000          city  None              0
# 905                 Dallas, TX    0.000000          city  None              0
# 906              Roseville, CA    0.000000          city  None              0
# 907            Los Angeles, CA    0.000000          city  None              0
# 908                Garland, TX    0.000000          city  None              0
# 909             Burlingame, CA    0.000000          city  None              0
# 910             Carmichael, CA    0.000000          city  None              0
# 911             Sacramento, CA    0.000000          city  None              0
# 912            Los Angeles, CA    0.000000          city  None              0
# 913             Carmichael, CA    0.000000          city  None              0
# 914            Los Angeles, CA -118.375030          city  None              0
# 915                 Irving, TX    0.000000          city  None              0
# 916            California, USA    0.000000         admin  None              0
# 917  Venice Beach, Los Angeles    0.000000  neighborhood  None              0
# 918            California, USA    0.000000         admin  None              0
# 919                 Dallas, TX  -96.800000          city  None              0
# 920          San Francisco, CA    0.000000          city  None              0
# 921            California, USA    0.000000         admin  None              0
# 922            California, USA    0.000000         admin  None              0
# 923            Los Angeles, CA    0.000000          city  None              0
# 924                 Texas, USA    0.000000         admin  None              0
# 925            California, USA    0.000000         admin  None              0
# 926                 Dallas, TX    0.000000          city  None              0
# 927                 Texas, USA    0.000000         admin  None              0
# 928                 Texas, USA    0.000000         admin  None              0
# 929            California, USA    0.000000         admin  None              0
# ..                         ...         ...           ...   ...            ...
# 970                 Irving, TX    0.000000          city  None              0
# 971          San Francisco, CA -122.418000          city  None              0
# 972          San Francisco, CA    0.000000          city  None              0
# 973          San Francisco, CA    0.000000          city  None              0
# 974            California, USA -118.827771         admin  None              0
# 975                 Texas, USA    0.000000         admin  None              0
# 976                 Dallas, TX  -96.679550          city  None              0
# 977            Los Angeles, CA    0.000000          city  None              0
# 978                 Texas, USA    0.000000         admin  None              0
# 979                 Dallas, TX    0.000000          city  None              0
# 980            Los Angeles, CA    0.000000          city  None              0
# 981            Los Angeles, CA    0.000000          city  None              0
# 982                 Texas, USA    0.000000         admin  None              0
# 983                 Dallas, TX    0.000000          city  None              0
# 984            Los Angeles, CA -118.249139          city  None              0
# 985                 Texas, USA    0.000000         admin  None              0
# 986                  Dixon, CA    0.000000          city  None              0
# 987                  Plano, TX    0.000000          city  None              0
# 988            Los Angeles, CA    0.000000          city  None              0
# 989            Los Angeles, CA    0.000000          city  None              0
# 990            California, USA    0.000000         admin  None              0
# 991            Los Angeles, CA -118.352790          city  None              0
# 992            Los Angeles, CA    0.000000          city  None              0
# 993          San Francisco, CA    0.000000          city  None              0
# 994                 Dallas, TX    0.000000          city  None              0
# 995          San Francisco, CA    0.000000          city  None              0
# 996                 Texas, USA    0.000000         admin  None              0
# 997            Los Angeles, CA    0.000000          city  None              0
# 998                 Texas, USA    0.000000         admin  None              0
# 999            Los Angeles, CA    0.000000          city  None              0
#
#     retweeted      screen_name                    time_zone  \
# 900     False     wifiboybands   Pacific Time (US & Canada)
# 901     False   euniceyoonikim   Eastern Time (US & Canada)
# 902     False     XOutDa_Lames   Central Time (US & Canada)
# 903     False      SonjaTrauss                         None
# 904     False           DKuzLA                         None
# 905     False       Gainzilla_   Pacific Time (US & Canada)
# 906     False       megdogwuff                         None
# 907     False    Fuckinq_Allie   Pacific Time (US & Canada)
# 908     False  keishawnleslie_   Pacific Time (US & Canada)
# 909     False       MindofMarc   Pacific Time (US & Canada)
# 910     False          OGCayyy       Atlantic Time (Canada)
# 911     False     Browns_Fan32   Central Time (US & Canada)
# 912     False    imonlychance_                         None
# 913     False     jonnygrant17                         None
# 914     False    Anthonygudkov                        Quito
# 915     False     mohammad1057   Central Time (US & Canada)
# 916     False   keijihainoVEVO   Pacific Time (US & Canada)
# 917     False       PowerLlama   Pacific Time (US & Canada)
# 918     False         beldeisa                       Alaska
# 919     False     FernormFaces   Central Time (US & Canada)
# 920     False    cindysofiayap                         None
# 921     False        seray1695   Pacific Time (US & Canada)
# 922     False      xxdestalynn                         None
# 923     False            ThcAx                       Alaska
# 924     False       terraxkerr                         None
# 925     False    PRAISEYEEZUSS                      Arizona
# 926     False        _surfresh  Mountain Time (US & Canada)
# 927     False    arielitoencar                         None
# 928     False   miranda_vining                         None
# 929     False       jcocaine11                         None
# ..        ...              ...                          ...
# 970     False         SlotCody                         None
# 971     False    Islandgirl145                         None
# 972     False   mannyfernandez   Pacific Time (US & Canada)
# 973     False       easealyssa                         None
# 974     False     _christyGIRL   Pacific Time (US & Canada)
# 975     False    meganrmcnulty   Central Time (US & Canada)
# 976     False  FUNcationNation   Pacific Time (US & Canada)
# 977     False          femmina   Pacific Time (US & Canada)
# 978     False     jojo_boi0101                         None
# 979     False   RedBootChicken                         None
# 980     False       LeeBrown_V   Pacific Time (US & Canada)
# 981     False      austin_6god                         None
# 982     False  justinrosgarcia                         None
# 983     False    tristenzeltee   Central Time (US & Canada)
# 984     False    hollievbrooks                       London
# 985     False        Ricka_Gee   Eastern Time (US & Canada)
# 986     False        dayysea__                         None
# 987     False       suckmytaki   Central Time (US & Canada)
# 988     False     ABDIELxOGshi                         None
# 989     False        alesparks                         None
# 990     False       ashleyy_sg                         None
# 991     False   homerdastoner1   Pacific Time (US & Canada)
# 992     False        KyleAbbot   Pacific Time (US & Canada)
# 993     False          Kazanjy                         None
# 994     False     TimMcMillan_   Pacific Time (US & Canada)
# 995     False  HaesemeyerMusic   Pacific Time (US & Canada)
# 996     False     raygeanhardy                         None
# 997     False  Globetrekker203   Pacific Time (US & Canada)
# 998     False        lowlifeze   Central Time (US & Canada)
# 999     False    imonlychance_                         None
#
#                                          tweet_content   usr
# 900  I'm like super amazing 😩👏🏻 https://t.co/Fv5AG2...  None
# 901  I just started the Handmaid's Tale and I thoug...  None
# 902  I think I'll take the sex over the head, ain't...  None
# 903  !! Blaming Jews for the revolution. https://t....  None
# 904  This is hilarious 😂 and obviously written by a...  None
# 905  Always good to come downtown. The vibe here ju...  None
# 906  This makes my ❤ happy! God bless you both! htt...  None
# 907  If my lonely heart could speak, you'd be surpr...  None
# 908          Ain't met her yet https://t.co/05Y6N3p1ud  None
# 909  @KeikakuKat Great. Ok. Last one from me. A mor...  None
# 910                       don't wanna see me winning 😭  None
# 911  Couldn't agree more, where's that cartoon http...  None
# 912  I need a bitch cut enough to blow my shit out ...  None
# 913                        "Kanye west is my main man"  None
# 914  🌴 just a great mood \n#LosAngeles #Cali #city ...  None
# 915    LMFAOO HOLYY SHITT 💀💀💀💀 https://t.co/Ttlxx1Fr51  None
# 916  @beeface it means hes a genious and you should...  None
# 917                   @ryamidon except for all of them  None
# 918  Just stumbled upon @jeweleaves but wow woman c...  None
# 919  No two clients will be the same. Every client ...  None
# 920  I'm seeing a lot of mommy's friends and I like...  None
# 921         Can I have him! 😩💗 https://t.co/h8dtWWHjzf  None
# 922  I wish I could take 3 steps backwards and focu...  None
# 923  I don't care about it anymore... I laugh about...  None
# 924                  You did it. You finally broke me.  None
# 925  @DreamzNitemares it's really not .... like at all  None
# 926              Your WCW washed up at the sink today.  None
# 927               Spanish is such a beautiful language  None
# 928  Living my best life eating cereal in bed and w...  None
# 929         I can't believe Robert found his joint 😂😂😂  None
# ..                                                 ...   ...
# 970  The fake exposing themselves with these #senio...  None
# 971  Early birthday fun in the city! \n#lovelife #t...  None
# 972  Some people say Silicon Valley is just a minds...  None
# 973  FFF SHE OLD ME RHIS YESTERDAY https://t.co/AII...  None
# 974  "Never get so busy making a living that you fo...  None
# 975  Lol @LeahRemini gotta love #fakenews https://t...  None
# 976  Hello Dallas! Is there enough FUN in your life...  None
# 977             @burnlittlelight @sillyhead I love you  None
# 978            Shoulda been coulda been all worked out  None
# 979  Reading is Fun! The Red Booted Chicken availab...  None
# 980  Following 5 random people who comment on my la...  None
# 981                          This weekend was good✊🏻❤️  None
# 982                                       it feel late  None
# 983  After this long ass day I would love a hot sho...  None
# 984  Ugly food, wonky veg... call it what you like,...  None
# 985  Or some I been saying this all my life 🤦🏼‍♀️ h...  None
# 986  I honestly send these "caution" texts so often...  None
# 987  The snap videos I send to Keyhole r qwhite emb...  None
# 988                             Up in SouthCentral HMU  None
# 989  I love being able to help my Mum clean her hom...  None
# 990  I love Rachel so fucking much ❤ #TheBachlorett...  None
# 991  🤘🏿Ohio! 🕵🏿🍀👅⭐️🔑 Black Irish mafia! 23 edition ...  None
# 992  LOOK #MurderSheWrote #TV #Pilot #Script - #Ang...  None
# 993  @migueldeicaza This is why "big boy / big girl...  None
# 994  LD made it his life to make sure others were h...  None
# 995  Hanging out in studio with new bad ass speaker...  None
# 996  calling yourself a 'has been' but you're a 'ne...  None
# 997  Demario took all the L's for the season. #TheB...  None
# 998  put me in a better mood, or not  https://t.co/...  None
# 999      Like how you ain't know where yo bitch was? 😭  None
#
# [100 rows x 20 columns]

# %%
from sklearn.feature_extraction.text import HashingVectorizer

# %%
hv= HashingVectorizer(non_negative=True)

# %%
hv.partial_fit(df['tweet_content'])
# Out:
# HashingVectorizer(analyzer='word', binary=False, decode_error='strict',
#          dtype=<class 'numpy.float64'>, encoding='utf-8', input='content',
#          lowercase=True, n_features=1048576, ngram_range=(1, 1),
#          non_negative=True, norm='l2', preprocessor=None, stop_words=None,
#          strip_accents=None, token_pattern='(?u)\\b\\w\\w+\\b',
#          tokenizer=None)

# %%
hv.transform(df['tweet_content'])
# Out:
# <52496x1048576 sparse matrix of type '<class 'numpy.float64'>'
# 	with 632939 stored elements in Compressed Sparse Row format>

# %%
art_text_cvec = hv.transform(article_text)
art_text_vec = tsvd.transform(art_text_cvec)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-48-77a14f4df9aa> in <module>()
# ----> 1 art_text_cvec = hv.transform(article_text)
#       2 art_text_vec = tsvd.transform(art_text_cvec)
#
# NameError: name 'article_text' is not defined

# %%
import psycopg2 as pg2
import psycopg2.extras as pgex
this_host='54.69.228.16'
this_user='postgres'
this_password='postgres'
conn = pg2.connect(host = this_host, 
                        user = this_user,
                        password = this_password)
from sklearn.feature_extraction.text import HashingVectorizer
hv= HashingVectorizer(non_negative=True,stop_words='english')
count = 0
while count < 5000: 
    sql_select = '''
    select * from tweets_20170529 where lang = 'en' limit 1000 offset {}
    '''.format(count)
    count += 1000
    print(count)
    cur = conn.cursor(cursor_factory=pgex.RealDictCursor)
    cur.execute(sql_select)
    rows = cur.fetchall()
    df = pd.DataFrame(rows)
    hv.partial_fit(df['tweet_content'])
    tweets_hv = hv.transform(df['tweet_content'].values.astype('U'))
conn.close()    
print('done')
# Out:
# 1000
# 2000
# 3000
# 4000
# 5000
# done

# %%
tweets_hv
# Out:
# <1000x1048576 sparse matrix of type '<class 'numpy.float64'>'
# 	with 6528 stored elements in Compressed Sparse Row format>

# %%
from sklearn.feature_extraction.text import CountVectorizer
cv= CountVectorizer(stop_words='english')

# %%
import psycopg2.extras as pgex
this_host='54.69.228.16'
this_user='postgres'
this_password='postgres'
conn = pg2.connect(host = this_host, 
                        user = this_user,
                        password = this_password)
from sklearn.feature_extraction.text import CountVectorizer
cv= CountVectorizer(stop_words='english')
count = 0
while count < 100000: 
    sql_select = '''
    select * from tweets_20170529 where lang = 'en' limit 1000 offset {}
    '''.format(count)
    count += 1000
    print(count)
    cur = conn.cursor(cursor_factory=pgex.RealDictCursor)
    cur.execute(sql_select)
    rows = cur.fetchall()
    df = pd.DataFrame(rows)
    cv. partial_fit(df['tweet_content'])
conn.close()    
print('done')
# Out:
# 1000
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-11-25b87fc8daa0> in <module>()
#      19     rows = cur.fetchall()
#      20     df = pd.DataFrame(rows)
# ---> 21     cv.partial_fit(df['tweet_content'])
#      22 conn.close()
#      23 print('done')
#
# AttributeError: 'CountVectorizer' object has no attribute 'partial_fit'

# %%
from sklearn.linear_model import SGDClassifier
from sklearn.pipeline import Pipeline
from sklearn.feature_extraction.text import HashingVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.multiclass import OneVsRestClassifier

classifier = Pipeline([
    ('vectorizer', HashingVectorizer(ngram_range=(1,4), non_negative=True)),
    ('tfidf', TfidfTransformer()),
    ('clf', OneVsRestClassifier(SGDClassifier())),
])

# %%
def partial_pipe_fit(pipeline_obj, df):
    X = pipeline_obj.named_steps['mapper'].fit_transform(df)
    Y = df['class']
    pipeline_obj.named_steps['clf'].partial_fit(X,Y)

# %%
# !pip install sklearn-pandas
# Out:
# Collecting sklearn-pandas
#   Downloading sklearn_pandas-1.4.0-py2.py3-none-any.whl
# Requirement already satisfied (use --upgrade to upgrade): pandas>=0.11.0 in /opt/conda/lib/python3.5/site-packages (from sklearn-pandas)
# Requirement already satisfied (use --upgrade to upgrade): scipy>=0.14 in /opt/conda/lib/python3.5/site-packages (from sklearn-pandas)
# Requirement already satisfied (use --upgrade to upgrade): numpy>=1.6.1 in /opt/conda/lib/python3.5/site-packages (from sklearn-pandas)
# Requirement already satisfied (use --upgrade to upgrade): scikit-learn>=0.15.0 in /opt/conda/lib/python3.5/site-packages (from sklearn-pandas)
# Requirement already satisfied (use --upgrade to upgrade): python-dateutil>=2 in /opt/conda/lib/python3.5/site-packages (from pandas>=0.11.0->sklearn-pandas)
# Requirement already satisfied (use --upgrade to upgrade): pytz>=2011k in /opt/conda/lib/python3.5/site-packages (from pandas>=0.11.0->sklearn-pandas)
# Requirement already satisfied (use --upgrade to upgrade): six>=1.5 in /opt/conda/lib/python3.5/site-packages (from python-dateutil>=2->pandas>=0.11.0->sklearn-pandas)
# Installing collected packages: sklearn-pandas
# Successfully installed sklearn-pandas-1.4.0
# You are using pip version 8.1.2, however version 9.0.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
from sklearn_pandas import DataFrameMapper, cross_val_score
to_vect = Pipeline([('vect', CountVectorizer(min_df=2, max_df=.9, ngram_range=(1, 1), max_features = 100)),
                            ('tfidf', TfidfTransformer())])
full_mapper = DataFrameMapper([
            ('norm_text', to_vect),
            ('norm_fname', to_vect), ])

full_pipe = Pipeline([('mapper', full_mapper), ('clf', SGDClassifier(n_iter=15, warm_start=True,
                                                                n_jobs=-1, random_state=42))])

# %%
full_mapper
# Out:
# DataFrameMapper(default=False, df_out=False,
#         features=[('norm_text', Pipeline(steps=[('vect', CountVectorizer(analyzer='word', binary=False, decode_error='strict',
#         dtype=<class 'numpy.int64'>, encoding='utf-8', input='content',
#         lowercase=True, max_df=0.9, max_features=100, min_df=2,
#         ngram_range=(1, 1), preprocessor=None...), ('tfidf', TfidfTransformer(norm='l2', smooth_idf=True, sublinear_tf=False, use_idf=True))]), {})],
#         input_df=False, sparse=False)

# %%
DataFrameMapper
# Out:
# sklearn_pandas.dataframe_mapper.DataFrameMapper
