# %%
import pandas as pd
import numpy as np
from sklearn.decomposition import TruncatedSVD
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
import random
from sklearn.metrics.pairwise import cosine_similarity
import math
import matplotlib.pyplot as plt
# %matplotlib inline
from nltk.tokenize import TweetTokenizer
import psycopg2 as pg2
import psycopg2.extras as pgex
this_host='34.211.59.66'
this_user='postgres'
this_password='postgres'
conn = pg2.connect(host = this_host, 
                        user = this_user,
                        password = this_password)

#sql_select = '''select created_at, location, tweet_content, cleaned_tweet, vector from tweets ORDER BY RANDOM() LIMIT 300000;'''
sql_select = '''select created_at, location, tweet_content, cleaned_tweet, hashtags from tweets where hashtags != 'None';'''
cur = conn.cursor(cursor_factory=pgex.RealDictCursor)
cur.execute(sql_select)
rows = cur.fetchall()
conn.close()
df = pd.DataFrame(rows)
df.reset_index(inplace = True)

# %%
df['created_datetime'] = pd.to_datetime(df['created_at'])
df['year'] = df.created_datetime.apply(lambda x: x.year)
df['month'] = df.created_datetime.apply(lambda x: x.month)
df['day'] = df.created_datetime.apply(lambda x: x.day)
df['dayofweek'] = df.created_datetime.apply(lambda x: x.dayofweek)
df['hour'] = df.created_datetime.apply(lambda x: x.hour)

# %%
df
# Out:
#        index                                      cleaned_tweet  \
# 0          0  even stranger is finding any true experts at t...
# 1          1                                  Stand By Myanmar
# 2          2  summer is here!! it's braid season #boxbraidsb...
# 3          3         my brothers driving has me soooooo dizzy 🤢
# 4          4  i'm late... i know.  #itfdb also, i was just y...
# 5          5  Don't let fool you. William F Buckley Jr was a...
# 6          6     The encompassed within hip- hop is beyond the
# 7          7                       LA Zoo Today 🙈🐨🐭🦇🐼🦊 . . . .
# 8          8                                    ❤ thank you!!!!
# 9          9                                   hollow man giggs
# 10        10  not recommending anymore men for jobs simply b...
# 11        11         i'd do it all "for you" . .  @ california
# 12        12                                 focus on the good.
# 13        13   listening to always and please tell me that w...
# 14        14            u sure henny? i could drag you, but...
# 15        15  the drums just needa release this album and i'...
# 16        16  congratulations keep working #alumni #dreamvis...
# 17        17  "the main thing is to keep the main thing, the...
# 18        18  Can you recommend anyone for this BI/DW Data A...
# 19        19             cant knock something for their passion
# 20        20                            i miss my piercings :'(
# 21        21   Media: What does mean? Sean Spice: Only a sma...
# 22        22   soooooo damn good for the soul~~ come get som...
# 23        23  really like this video of me and maria from sa...
# 24        24  in a world where hurt &amp; hate seems inescap...
# 25        25  who wants to bet he is going to be asked to ta...
# 26        26                                Of course he did 🙄
# 27        27   "A super bundle." 5 novels by 5 best selling ...
# 28        28  #1oaktuesdays    guest list  tables  j.r. 818-...
# 29        29  ( ) June gloom in LA today - excited for summe...
# ...      ...                                                ...
# 86461  86461  want to work at languageline solutions? we're ...
# 86462  86462  interested in a #job in #simivalley, ca? this ...
# 86463  86463  #whitememorialmedicalcenter 46th annual employ...
# 86464  86464  join the fresenius medical care team! see our ...
# 86465  86465  see our latest #losangeles, ca #job and click ...
# 86466  86466  #teamcolbert ad rates for comey thurs. hearing...
# 86467  86467  a5: ss can listen to each other's ideas, colla...
# 86468  86468                               #fairnessforcasting
# 86469  86469  if you're a "concerned" #irvine taxpayer, why ...
# 86470  86470   ad rates for comey thurs. hearings on cable r...
# 86471  86471  today was a little tricky  #phantom4 #dji #dro...
# 86472  86472  no bad angles styled by #jswainphoto #mariatul...
# 86473  86473  want to work in #irvine, ca? view our latest o...
# 86474  86474  a5: projects that encourage ss to take thought...
# 86475  86475  can you recommend anyone for this #job? admini...
# 86476  86476  call me popeye cuz i gets my spinach.... grrrr...
# 86477  86477   ad rates for comey thurs. hearings on cable r...
# 86478  86478  see our latest #losangeles, ca #job and click ...
# 86479  86479  crash blocking the second lane from the left i...
# 86480  86480  see our latest #olympicvalley, ca #job and cli...
# 86481  86481   ad rates for comey thurs. hearings on cable r...
# 86482  86482  #merylstreep #hollywood #la #california @ tcl ...
# 86483  86483  mofo's out here just jerkin off and bustin in ...
# 86484  86484  it actually saddens me that people in #la take...
# 86485  86485  #friends #strongcatmedia #losglobos #losangele...
# 86486  86486  literally two 2017 things getting me through t...
# 86487  86487   ad rates for comey thurs. hearings on cable r...
# 86488  86488  love #maps? love #longtrails? you love this ma...
# 86489  86489  we're #hiring! click to apply: behavior suppor...
# 86490  86490   ad rates for comey thurs. hearings on cable r...
#
#                            created_at  \
# 0      Wed Jun 07 02:27:44 +0000 2017
# 1      Wed May 31 23:54:39 +0000 2017
# 2      Wed Jun 07 02:27:44 +0000 2017
# 3      Wed Jun 07 02:27:45 +0000 2017
# 4      Wed Jun 07 02:27:46 +0000 2017
# 5      Wed May 31 23:54:25 +0000 2017
# 6      Wed May 31 23:54:29 +0000 2017
# 7      Wed May 31 23:54:30 +0000 2017
# 8      Wed Jun 07 02:27:48 +0000 2017
# 9      Wed Jun 07 02:27:49 +0000 2017
# 10     Wed Jun 07 02:27:49 +0000 2017
# 11     Wed Jun 07 02:27:49 +0000 2017
# 12     Wed Jun 07 02:27:49 +0000 2017
# 13     Wed Jun 07 02:27:49 +0000 2017
# 14     Wed Jun 07 02:27:50 +0000 2017
# 15     Wed Jun 07 02:27:51 +0000 2017
# 16     Sun Jun 04 18:45:54 +0000 2017
# 17     Wed Jun 07 02:27:50 +0000 2017
# 18     Wed May 31 23:55:46 +0000 2017
# 19     Wed Jun 07 02:27:51 +0000 2017
# 20     Wed Jun 07 02:27:51 +0000 2017
# 21     Wed May 31 23:55:58 +0000 2017
# 22     Wed May 31 23:56:28 +0000 2017
# 23     Wed Jun 07 02:27:51 +0000 2017
# 24     Wed Jun 07 02:27:51 +0000 2017
# 25     Wed Jun 07 02:27:52 +0000 2017
# 26     Wed May 31 23:56:29 +0000 2017
# 27     Wed May 31 23:56:28 +0000 2017
# 28     Wed Jun 07 02:27:52 +0000 2017
# 29     Wed May 31 23:56:29 +0000 2017
# ...                               ...
# 86461  Wed Jun 07 00:36:52 +0000 2017
# 86462  Wed Jun 07 00:37:01 +0000 2017
# 86463  Wed Jun 07 00:37:11 +0000 2017
# 86464  Wed Jun 07 00:37:23 +0000 2017
# 86465  Wed Jun 07 00:37:35 +0000 2017
# 86466  Wed Jun 07 00:37:52 +0000 2017
# 86467  Wed Jun 07 00:38:06 +0000 2017
# 86468  Wed Jun 07 00:38:10 +0000 2017
# 86469  Wed Jun 07 00:38:29 +0000 2017
# 86470  Wed Jun 07 00:38:36 +0000 2017
# 86471  Wed Jun 07 00:38:41 +0000 2017
# 86472  Wed Jun 07 00:38:46 +0000 2017
# 86473  Wed Jun 07 00:38:50 +0000 2017
# 86474  Wed Jun 07 00:39:03 +0000 2017
# 86475  Wed Jun 07 00:39:10 +0000 2017
# 86476  Wed Jun 07 00:39:35 +0000 2017
# 86477  Wed Jun 07 00:39:41 +0000 2017
# 86478  Wed Jun 07 00:39:55 +0000 2017
# 86479  Wed Jun 07 00:40:04 +0000 2017
# 86480  Wed Jun 07 00:40:15 +0000 2017
# 86481  Wed Jun 07 00:40:16 +0000 2017
# 86482  Wed Jun 07 00:40:29 +0000 2017
# 86483  Wed Jun 07 00:40:35 +0000 2017
# 86484  Wed Jun 07 00:40:49 +0000 2017
# 86485  Wed Jun 07 00:41:03 +0000 2017
# 86486  Wed Jun 07 00:41:04 +0000 2017
# 86487  Wed Jun 07 00:41:09 +0000 2017
# 86488  Wed Jun 07 00:41:28 +0000 2017
# 86489  Wed Jun 07 00:41:35 +0000 2017
# 86490  Wed Jun 07 00:41:42 +0000 2017
#
#                                                 hashtags            location  \
# 0                                                 drones         burbank, ca
# 1                                      makeamovieforeign     los angeles, ca
# 2                                 boxbraidsbyme flawless     los angeles, ca
# 3                                 boxbraidsbyme flawless     california, usa
# 4                                                  itfdb     los angeles, ca
# 5                                               hardball     los angeles, ca
# 6                               energy audible spectrum      los angeles, ca
# 7       beverlyhills90210 losangeles lifestyle lazoo ...     los angeles, ca
# 8                                                  itfdb         burbank, ca
# 9                                                  itfdb     los angeles, ca
# 10                                                 itfdb     los angeles, ca
# 11                                                 itfdb     california, usa
# 12                                                 itfdb      long beach, ca
# 13                                                 itfdb     los angeles, ca
# 14                                                 itfdb     los angeles, ca
# 15                                                 itfdb         anaheim, ca
# 16                                    alumni dreamvision          orange, ca
# 17                                              patriley      the conga room
# 18                                 job losangeles hiring     los angeles, ca
# 19                                              patriley     california, usa
# 20                                              patriley        el monte, ca
# 21                                               covfefe     los angeles, ca
# 22                                           jazzinheels     los angeles, ca
# 23                                              patriley           azusa, ca
# 24                                              patriley     los angeles, ca
# 25                                              patriley     los angeles, ca
# 26                                               covfefe     los angeles, ca
# 27                       mgtab historical bundle romance     california, usa
# 28                                          1oaktuesdays  west hollywood, ca
# 29                                             throwback     los angeles, ca
# ...                                                  ...                 ...
# 86461               hiring gardengrove workfromhome wahm    garden grove, ca
# 86462        job simivalley hospitality hiring careerarc     simi valley, ca
# 86463                         whitememorialmedicalcenter        alhambra, ca
# 86464              job dialysis healthcare orange hiring          orange, ca
# 86465                         losangeles job engineering     los angeles, ca
# 86466                              teamcolbert rexreedjr     los angeles, ca
# 86467                                       gafe4littles     california, usa
# 86468                                 fairnessforcasting  west hollywood, ca
# 86469                                             irvine          irvine, ca
# 86470                                          rexreedjr     los angeles, ca
# 86471                      phantom4 dji drone dronecrash        pasadena, ca
# 86472              jswainphoto mariatuleeva jessicafang      los angeles, ca
# 86473        irvine accounting job jobs hiring careerarc          irvine, ca
# 86474                                       gafe4littles     california, usa
# 86475             job clerical pasadena hiring careerarc        pasadena, ca
# 86476   realthugmusic thugbible thuglife lionfood lac...        the albright
# 86477                                          rexreedjr     los angeles, ca
# 86478                    losangeles job warehouse hiring     los angeles, ca
# 86479                                     bell latraffic            bell, ca
# 86480     olympicvalley job hospitality hiring careerarc     california, usa
# 86481                                          rexreedjr     los angeles, ca
# 86482                merylstreep hollywood la california     los angeles, ca
# 86483                                    homeless savage     california, usa
# 86484                                                 la     los angeles, ca
# 86485   friends strongcatmedia losglobos losangeles e...     club los globos
# 86486                                silvereye twinpeaks      long beach, ca
# 86487                                          rexreedjr     los angeles, ca
# 86488                   maps longtrails backpackinggoals    garden grove, ca
# 86489   hiring autism mentalhealth healthwelfare losa...     los angeles, ca
# 86490                                          rexreedjr     los angeles, ca
#
#                                            tweet_content    created_datetime  \
# 0      even stranger is finding any true experts at t... 2017-06-07 02:27:44
# 1                    stand by myanmar #makeamovieforeign 2017-05-31 23:54:39
# 2      🌞summer is here!! it's braid season #boxbraids... 2017-06-07 02:27:44
# 3             my brothers driving has me soooooo dizzy 🤢 2017-06-07 02:27:45
# 4      i'm late... i know. 😫 #itfdb also, i was just ... 2017-06-07 02:27:46
# 5      don't let #hardball fool you. william f buckle... 2017-05-31 23:54:25
# 6      the #energy encompassed within hip- hop is bey... 2017-05-31 23:54:29
# 7      la zoo today 🙈🐨🐭🦇🐼🦊 . . . . #beverlyhills90210... 2017-05-31 23:54:30
# 8                            @matchapon_ ❤ thank you!!!! 2017-06-07 02:27:48
# 9                                       hollow man giggs 2017-06-07 02:27:49
# 10     not recommending anymore men for jobs simply b... 2017-06-07 02:27:49
# 11     i'd do it all "for you" . . 💗 @ california htt... 2017-06-07 02:27:49
# 12                                    focus on the good. 2017-06-07 02:27:49
# 13     @wearewavedash listening to always and please ... 2017-06-07 02:27:49
# 14     @danielswavey u sure henny? i could drag you, ... 2017-06-07 02:27:50
# 15     the drums just needa release this album and i'... 2017-06-07 02:27:51
# 16     congratulations  keep working @dv2k15 #alumni ... 2017-06-04 18:45:54
# 17     "the main thing is to keep the main thing, the... 2017-06-07 02:27:50
# 18     can you recommend anyone for this #job? bi/dw ... 2017-05-31 23:55:46
# 19                cant knock something for their passion 2017-06-07 02:27:51
# 20                               i miss my piercings :'( 2017-06-07 02:27:51
# 21     @starbuckcovfefe media: what does #covfefe mea... 2017-05-31 23:55:58
# 22     #jazzinheels soooooo damn good for the soul~~ ... 2017-05-31 23:56:28
# 23     really like this video of me and maria from sa... 2017-06-07 02:27:51
# 24     in a world where hurt &amp; hate seems inescap... 2017-06-07 02:27:51
# 25     who wants to bet he is going to be asked to ta... 2017-06-07 02:27:52
# 26     of course he did 🙄 #covfefe https://t.co/qtyq1... 2017-05-31 23:56:29
# 27     #mgtab "a super #historical bundle."#romance 5... 2017-05-31 23:56:28
# 28     #1oaktuesdays 🎥 @mikey_danger 🎶 @djmarkdaspot ... 2017-06-07 02:27:52
# 29     ( #throwback ) june gloom in la today - excite... 2017-05-31 23:56:29
# ...                                                  ...                 ...
# 86461  want to work at languageline solutions? we're ... 2017-06-07 00:36:52
# 86462  interested in a #job in #simivalley, ca? this ... 2017-06-07 00:37:01
# 86463  #whitememorialmedicalcenter 46th annual employ... 2017-06-07 00:37:11
# 86464  join the fresenius medical care team! see our ... 2017-06-07 00:37:23
# 86465  see our latest #losangeles, ca #job and click ... 2017-06-07 00:37:35
# 86466  #teamcolbert  ad rates for comey thurs. hearin... 2017-06-07 00:37:52
# 86467  a5: ss can listen to each other's ideas, colla... 2017-06-07 00:38:06
# 86468        #fairnessforcasting https://t.co/rfpfjhoh0h 2017-06-07 00:38:10
# 86469  if you're a "concerned" #irvine taxpayer, why ... 2017-06-07 00:38:29
# 86470  @colbyhall  ad rates for comey thurs. hearings... 2017-06-07 00:38:36
# 86471  today was a little tricky 😜 #phantom4 #dji #dr... 2017-06-07 00:38:41
# 86472  no bad angles  @mariiatuleeva  styled by @jess... 2017-06-07 00:38:46
# 86473  want to work in #irvine, ca? view our latest o... 2017-06-07 00:38:50
# 86474  a5: projects that encourage ss to take thought... 2017-06-07 00:39:03
# 86475  can you recommend anyone for this #job? admini... 2017-06-07 00:39:10
# 86476  call me popeye cuz i gets my spinach.... grrrr... 2017-06-07 00:39:35
# 86477  @jameswolcott  ad rates for comey thurs. heari... 2017-06-07 00:39:41
# 86478  see our latest #losangeles, ca #job and click ... 2017-06-07 00:39:55
# 86479  crash blocking the second lane from the left i... 2017-06-07 00:40:04
# 86480  see our latest #olympicvalley, ca #job and cli... 2017-06-07 00:40:15
# 86481  @evan_mcmullin  ad rates for comey thurs. hear... 2017-06-07 00:40:16
# 86482  #merylstreep #hollywood #la #california @ tcl ... 2017-06-07 00:40:29
# 86483  mofo's out here just jerkin off and bustin in ... 2017-06-07 00:40:35
# 86484  it actually saddens me that people in #la take... 2017-06-07 00:40:49
# 86485  #friends @bassforbreasts #strongcatmedia #losg... 2017-06-07 00:41:03
# 86486  literally two 2017 things getting me through t... 2017-06-07 00:41:04
# 86487  @hunterdk  ad rates for comey thurs. hearings ... 2017-06-07 00:41:09
# 86488  love #maps?  love #longtrails? you love this @... 2017-06-07 00:41:28
# 86489  we're #hiring! click to apply: behavior suppor... 2017-06-07 00:41:35
# 86490  @robreiner  ad rates for comey thurs. hearings... 2017-06-07 00:41:42
#
#        year  month  day  dayofweek  hour
# 0      2017      6    7          2     2
# 1      2017      5   31          2    23
# 2      2017      6    7          2     2
# 3      2017      6    7          2     2
# 4      2017      6    7          2     2
# 5      2017      5   31          2    23
# 6      2017      5   31          2    23
# 7      2017      5   31          2    23
# 8      2017      6    7          2     2
# 9      2017      6    7          2     2
# 10     2017      6    7          2     2
# 11     2017      6    7          2     2
# 12     2017      6    7          2     2
# 13     2017      6    7          2     2
# 14     2017      6    7          2     2
# 15     2017      6    7          2     2
# 16     2017      6    4          6    18
# 17     2017      6    7          2     2
# 18     2017      5   31          2    23
# 19     2017      6    7          2     2
# 20     2017      6    7          2     2
# 21     2017      5   31          2    23
# 22     2017      5   31          2    23
# 23     2017      6    7          2     2
# 24     2017      6    7          2     2
# 25     2017      6    7          2     2
# 26     2017      5   31          2    23
# 27     2017      5   31          2    23
# 28     2017      6    7          2     2
# 29     2017      5   31          2    23
# ...     ...    ...  ...        ...   ...
# 86461  2017      6    7          2     0
# 86462  2017      6    7          2     0
# 86463  2017      6    7          2     0
# 86464  2017      6    7          2     0
# 86465  2017      6    7          2     0
# 86466  2017      6    7          2     0
# 86467  2017      6    7          2     0
# 86468  2017      6    7          2     0
# 86469  2017      6    7          2     0
# 86470  2017      6    7          2     0
# 86471  2017      6    7          2     0
# 86472  2017      6    7          2     0
# 86473  2017      6    7          2     0
# 86474  2017      6    7          2     0
# 86475  2017      6    7          2     0
# 86476  2017      6    7          2     0
# 86477  2017      6    7          2     0
# 86478  2017      6    7          2     0
# 86479  2017      6    7          2     0
# 86480  2017      6    7          2     0
# 86481  2017      6    7          2     0
# 86482  2017      6    7          2     0
# 86483  2017      6    7          2     0
# 86484  2017      6    7          2     0
# 86485  2017      6    7          2     0
# 86486  2017      6    7          2     0
# 86487  2017      6    7          2     0
# 86488  2017      6    7          2     0
# 86489  2017      6    7          2     0
# 86490  2017      6    7          2     0
#
# [86491 rows x 12 columns]

# %%
tfidf_vectorizer = TfidfVectorizer(min_df = 1, stop_words = 'english')
hashtag_tfidf = tfidf_vectorizer.fit_transform(df['hashtags'].values.astype('U'))

# %%
import pickle
# !pip install redis
import redis
redis_ip = '34.211.59.66'
r = redis.StrictRedis(redis_ip)
hashtag_tfidf = pickle.dumps(hashtag_tfidf)
r.set('hashtag_tfidf', hashtag_tfidf)
r.keys()
# Out:
# Requirement already satisfied (use --upgrade to upgrade): redis in /opt/conda/lib/python3.5/site-packages
# You are using pip version 8.1.2, however version 9.0.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.
# [b'tweet_tfidf_transform',
#  b'tweet_tfidf_model',
#  b'tweet_tfidf_model_fit',
#  b'tweet_SVD_model_fit',
#  b'hashtag_tfidf',
#  b'SVD_model_fit']

# %%
#r.flushall()
