# %%
import pandas as pd
import numpy as np
from sklearn.decomposition import TruncatedSVD
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
import random
from sklearn.metrics.pairwise import cosine_similarity
import math
import tqdm
import matplotlib.pyplot as plt
# %matplotlib inline
# !pip install wordcloud
from wordcloud import WordCloud, STOPWORDS
# Out:
# Requirement already satisfied: wordcloud in /opt/conda/lib/python3.5/site-packages
# Requirement already satisfied: matplotlib in /opt/conda/lib/python3.5/site-packages (from wordcloud)
# Requirement already satisfied: numpy>=1.6.1 in /opt/conda/lib/python3.5/site-packages (from wordcloud)
# Requirement already satisfied: pillow in /opt/conda/lib/python3.5/site-packages (from wordcloud)
# Requirement already satisfied: six>=1.10 in /opt/conda/lib/python3.5/site-packages (from matplotlib->wordcloud)
# Requirement already satisfied: python-dateutil in /opt/conda/lib/python3.5/site-packages (from matplotlib->wordcloud)
# Requirement already satisfied: pytz in /opt/conda/lib/python3.5/site-packages (from matplotlib->wordcloud)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.5/site-packages/cycler-0.10.0-py3.5.egg (from matplotlib->wordcloud)
# Requirement already satisfied: pyparsing!=2.0.4,!=2.1.2,!=2.1.6,>=1.5.6 in /opt/conda/lib/python3.5/site-packages (from matplotlib->wordcloud)
# Requirement already satisfied: olefile in /opt/conda/lib/python3.5/site-packages (from pillow->wordcloud)

# %%
import psycopg2 as pg2
import psycopg2.extras as pgex
this_host='34.211.59.66'
this_user='postgres'
this_password='postgres'
conn = pg2.connect(host = this_host, 
                        user = this_user,
                        password = this_password)

sql_select = '''select created_at, location, tweet_content, cleaned_tweet, hashtags from tweets;'''

cur = conn.cursor(cursor_factory=pgex.RealDictCursor)
cur.execute(sql_select)
rows = cur.fetchall()
conn.close()
df = pd.DataFrame(rows)
df.reset_index(inplace = True)

# %%
import pickle
# !pip install redis
import redis
redis_ip = '34.211.59.66'
r = redis.StrictRedis(redis_ip)
r.keys()
# Out:
# Requirement already satisfied: redis in /opt/conda/lib/python3.5/site-packages
# [b'tweet_tfidf_fit_transform',
#  b'tweet_SVD_fit',
#  b'temp_hash_count_12hr',
#  b'hashtags_tfidf_fit_transform',
#  b'hashtags_countvec_fit_temp',
#  b'tweet_tfidf_fit',
#  b'hashtags_countvec_fit',
#  b'hashtag_tfidf',
#  b'hashtags_countvec_fit_transform']

# %%
TFIDF_fit = pickle.loads(r.get('tweet_tfidf_fit'))
SVD_fit = pickle.loads(r.get('tweet_SVD_fit'))

# %%
def event_tweet_count(event):
    event = event.lower()
    event_tweet = df[df['cleaned_tweet'].str.contains((event))]
    return len(event_tweet)

# %%
def tweets_event_ab_test(event):
    event = event.lower()
    event_tweet = df[df['cleaned_tweet'].str.contains((event))]
    event_tweet.reset_index(inplace = True)
    
    A_index = list(range(event_tweet.shape[0]))
    random.shuffle(A_index)
    
    n = int(round((event_tweet_count(event))*0.2,0))
    A1_index = []
    for i in range(n):
        A1_index.append(A_index.pop())
    
    A1 = event_tweet.iloc[A1_index,:]
    A1_vec = np.array([SVD_fit.transform(TFIDF_fit.transform([i])).ravel() for i in A1['cleaned_tweet']])

    A2 = event_tweet.iloc[A_index,:] 
    #A2.reset_index(inplace = True)
    A2_vec = np.array([SVD_fit.transform(TFIDF_fit.transform([i])).ravel() for i in A2['cleaned_tweet']])
    non_event_tweet = df[~df['cleaned_tweet'].str.contains(('event'))]
    non_event_tweet.reset_index(inplace = True)
    
    B_index = list(range(non_event_tweet.shape[0]))
    random.shuffle(B_index)
    n = n
    B1_index = []
    for i in range(n):
        B1_index.append(B_index.pop())
    m = A2.shape[0]
    B2_index = []
    for i in range(m):
        B2_index.append(B_index.pop())  
    
    B1 = non_event_tweet.iloc[B1_index,:]
    B1_vec = np.array([SVD_fit.transform(TFIDF_fit.transform([i])).ravel() for i in B1['cleaned_tweet']])
    
    B2 = non_event_tweet.iloc[B2_index,:]
    B2_vec = np.array([SVD_fit.transform(TFIDF_fit.transform([i])).ravel() for i in B2['cleaned_tweet']])
    
    A1_vec_mean = np.mean(A1_vec, axis=0)
    A2_vec_mean = np.mean(A2_vec, axis=0)
    B1_vec_mean = np.mean(B1_vec, axis=0)
    B2_vec_mean = np.mean(B2_vec, axis=0)
    
    a1a2 = cosine_similarity(A1_vec_mean.reshape(1,-1),A2_vec_mean.reshape(1,-1))[0][0]
    b1b2 = cosine_similarity(B2_vec_mean.reshape(1,-1),B1_vec_mean.reshape(1,-1))[0][0]
    a1b1 = cosine_similarity(A1_vec_mean.reshape(1,-1),B1_vec_mean.reshape(1,-1))[0][0]
    a2b2 = cosine_similarity(A2_vec_mean.reshape(1,-1),B2_vec_mean.reshape(1,-1))[0][0]
   
    a2_consim_list = []
    for i in range(min(n,m)):  
        a2_consim_list.append(cosine_similarity(A2_vec[i].reshape(1,-1),A1_vec_mean.reshape(1,-1))[0][0])
    a2_mean = np.mean(np.array(a2_consim_list))
    a2_std = np.std(np.array(a2_consim_list))
    
    b2_consim_list = []
    for i in range(min(n,m)):  
        b2_consim_list.append(cosine_similarity(B2_vec[i].reshape(1,-1),B1_vec_mean.reshape(1,-1))[0][0])
    b2_mean = np.mean(b2_consim_list)
    b2_std = np.std(b2_consim_list)
    
    a1b2_consim_list = []
    for i in range(min(n,m)):  
        a1b2_consim_list.append((cosine_similarity(B2_vec[i].reshape(1,-1),A1_vec_mean.reshape(1,-1))[0][0]))
    a1b2_mean = np.mean(a1b2_consim_list)
    a1b2_std = np.std(a1b2_consim_list)
    
    print('A1|A2: ',round(a1a2,3),'\n'
                'B1|B2: ',round(b1b2,3), '\n\n'
                'A1|B1: ',round(a1b1,3), '\n'
                'A2|B2: ', round(a2b2,3), '\n\n'
                'Cosine Similarity Mean of A2 to A1', round(a2_mean,3), '\n'
                'Cosine Similarity Mean of B2 to B1', round(b2_mean,3), '\n'
                'Cosine Similarity Mean of B2 to A1', round(a1b2_mean,3), '\n\n'
                'Cosine Similarity STD of A2 to A1', round(a2_std,3), '\n'
                'Cosine Similarity STD of B2 to B1', round(b2_std,3), '\n'
                'Cosine Similarity STD of B2 to A1', round(a1b2_std,3), '\n'                 
                )
    
    return a2_consim_list, b2_consim_list

# %%
def check_score_cluster(event,check_by_score = .7,high_score = .9):
    event = event.lower()
    event_tweet = df[df['cleaned_tweet'].str.contains((event))]
    event_tweet.reset_index(inplace = True, drop=True)
    A_index = list(range(event_tweet.shape[0]))
    random.shuffle(A_index)

    n = int(round((event_tweet_count(event))*0.5,0))
    A1_index = []
    for i in range(n):
        A1_index.append(A_index.pop())

    A1 = event_tweet.iloc[A1_index,:]
    A1.reset_index(inplace = True, drop=True)
    A1_vec = SVD_fit.transform(TFIDF_fit.transform(A1['cleaned_tweet']))

    A2 = event_tweet.iloc[A_index,:] 
    A2_vec = SVD_fit.transform(TFIDF_fit.transform(A2['cleaned_tweet']))
    A1_vec_mean = np.mean(A1_vec, axis=0)
    A2_vec_mean = np.mean(A2_vec, axis=0)

    consim_twt_list = []
    for i in range(len(A1)):  
        consim_twt_list.append((cosine_similarity(A1_vec[i].reshape(1,-1),A2_vec_mean.reshape(1,-1))[0][0], A1['cleaned_tweet'][i]))
    #pd.options.display.max_colwidth = 200
    result = pd.DataFrame(consim_twt_list, columns = ['score','tweet'])
    cluster1 = result[result['score']>high_score].sort_values('score', ascending = False)
    cluster2 = result[((result['score']<(check_by_score+.05)) & (result['score']>(check_by_score-.05)))]\
                .sort_values('score', ascending = False)
    return pd.concat([cluster1.reset_index().head(30), cluster2.reset_index().head(30)], axis=1)

# %%
def Top_scored_tweets_in_B(event, n = 10000):
    event = event.lower()
    A = df[df['cleaned_tweet'].str.contains((event))]
    A.reset_index(inplace = True, drop=True)
    A_vec = SVD_fit.transform(TFIDF_fit.transform(A['cleaned_tweet']))
    A_vec_mean = np.average(A_vec, axis=0)
       
    B = df[~df['cleaned_tweet'].str.contains((event))]
    B_index = list(range(B.shape[0]))
    random.shuffle(B_index)
    n = n
    B1_index = []
    for i in range(n):
        B1_index.append(B_index.pop())
        
    B1 = B.iloc[B1_index,:]
    B1.reset_index(inplace = True, drop=True)
    B1_vec = SVD_fit.transform(TFIDF_fit.transform(B1['cleaned_tweet']))
    
    consim_twt_list = []
    for i in range(n):  
        consim_twt_list.append((cosine_similarity(B1_vec[i].reshape(1,-1),A_vec_mean.reshape(1,-1))[0][0], B1['cleaned_tweet'][i]))
    pd.options.display.max_colwidth = 200
    result = pd.DataFrame(consim_twt_list, columns = ['score','tweet'])
    cluster = result[result['score']>.7].sort_values('score', ascending = False)
    pd.set_option('display.max_colwidth', -1)
    return cluster.head(20)

# %%
stopwords = set(STOPWORDS)
wc = WordCloud(width=1600, height=800, background_color='white', \
               relative_scaling=1, stopwords=stopwords, colormap='copper').generate(' '.join(i for i in df['cleaned_tweet']))


plt.figure(figsize=(20,10))
plt.imshow(wc)
plt.axis("off")
plt.show()

# %%
print('Event Tweets (paris|climate): ', event_tweet_count('paris|climate'))
A, B = tweets_event_ab_test('paris|climate')
plt.scatter(range(len(A)), A, c = 'g')
plt.scatter(range(len(B)), B, c = 'r')
plt.ylim(-.1,1)
# Out:
# Event Tweets (paris|climate):  2627
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-16-edd2fdf99f01> in <module>()
#       1 print('Event Tweets (paris|climate): ', event_tweet_count('paris|climate'))
# ----> 2 A, B = tweets_event_ab_test('paris|climate')
#       3 plt.scatter(range(len(A)), A, c = 'g')
#       4 plt.scatter(range(len(B)), B, c = 'r')
#       5 plt.ylim(-.1,1)
#
# <ipython-input-7-009c6a44e869> in tweets_event_ab_test(event)
#      13
#      14     A1 = event_tweet.iloc[A1_index,:]
# ---> 15     A1_vec = np.array([SVD_fit.transform(TFIDF_fit.transform([i])).ravel() for i in A1['cleaned_tweet']])
#      16
#      17     A2 = event_tweet.iloc[A_index,:]
#
# <ipython-input-7-009c6a44e869> in <listcomp>(.0)
#      13
#      14     A1 = event_tweet.iloc[A1_index,:]
# ---> 15     A1_vec = np.array([SVD_fit.transform(TFIDF_fit.transform([i])).ravel() for i in A1['cleaned_tweet']])
#      16
#      17     A2 = event_tweet.iloc[A_index,:]
#
# /opt/conda/lib/python3.5/site-packages/sklearn/decomposition/truncated_svd.py in transform(self, X)
#     202         """
#     203         X = check_array(X, accept_sparse='csr')
# --> 204         return safe_sparse_dot(X, self.components_.T)
#     205
#     206     def inverse_transform(self, X):
#
# /opt/conda/lib/python3.5/site-packages/sklearn/utils/extmath.py in safe_sparse_dot(a, b, dense_output)
#     182     """
#     183     if issparse(a) or issparse(b):
# --> 184         ret = a * b
#     185         if dense_output and hasattr(ret, "toarray"):
#     186             ret = ret.toarray()
#
# /opt/conda/lib/python3.5/site-packages/scipy/sparse/base.py in __mul__(self, other)
#     358                 return self._mul_vector(other.ravel()).reshape(M, 1)
#     359             elif other.ndim == 2 and other.shape[0] == N:
# --> 360                 return self._mul_multivector(other)
#     361
#     362         if isscalarlike(other):
#
# /opt/conda/lib/python3.5/site-packages/scipy/sparse/compressed.py in _mul_multivector(self, other)
#     509         # csr_matvecs or csc_matvecs
#     510         fn = getattr(_sparsetools,self.format + '_matvecs')
# --> 511         fn(M, N, n_vecs, self.indptr, self.indices, self.data, other.ravel(), result.ravel())
#     512
#     513         return result
#
# KeyboardInterrupt:

# %%
check_score_cluster('paris|climate',.3, .7)

# %%
print('Event Tweets (nbafinals): ', event_tweet_count('nbafinals'))
A, B = tweets_event_ab_test('nbafinals')
plt.scatter(range(len(A)), A, c = 'g')
plt.scatter(range(len(B)), B, c = 'r')
plt.ylim(-.1,1.2)

# %%
#check high score tweets (>0.9) versus tweets with clustered scores 
check_score_cluster('nbafinal',.7)

# %%
check_score_cluster('nbafinal',.2)
# Out:
#     index     score                                              tweet  index  \
# 0     515  0.951261  curry takes lebron to the hoop: "this is where...    163
# 1      17  0.949416  think #lebronjames wished #cavaliers traded #k...    225
# 2      84  0.949136  #lebronjames critics gonna blame him but he's ...    442
# 3     440  0.948509  #lebron getting stomped by #durant and #curry ...    151
# 4     261  0.945784      #gsw #nbafinals #lebronjames @ interstate 40     391
# 5     306  0.945610  that kd 3 in lebron's face was the defining pl...    192
# 6     556  0.945594  and take ur l's like a man #nbafinals #goldens...    368
# 7     289  0.945453           kd full on just pushed lebron #nbafinals    506
# 8     231  0.945448     kd clutch , lebron takes another l #nbafinals     269
# 9     369  0.945448      kd clutch , lebron takes another l #nbafinals    245
# 10    424  0.945445  lebron is trying to get kd to react for an off...    386
# 11    447  0.944239  lebron james going back to the lab #nbafinals ...    244
# 12    335  0.944086  i feel like durants hard foul on lebron there ...    167
# 13    103  0.943753  everyone saying lebron is goat but he quit and...    210
# 14    526  0.943675  if there is a lebron james and kevin durant ra...    174
# 15    524  0.943131  looked like lebron just kicked that dude in th...     87
# 16    228  0.943109  less than 2 minutes to play in a pivotal game ...    206
# 17    535  0.943081  two hot nights for durant. give the man the fi...     35
# 18    324  0.942924  lebron is the king, which is why he is a royal...    146
# 19     88  0.942627  and y'all say lebron is better than kobe/jorda...    215
# 20     90  0.942338   #lebron ties magicjohnson for most triple-dou...    327
# 21    497  0.942257  lebron definitely misses layups better than mj...     12
# 22    219  0.942020   matt barnes vandalized lebron's house #nbafinals    145
# 23    395  0.941995  igoudala just rejected lebron so hard his hair...    367
# 24    328  0.941994  lebron kicked iguodala in the groin. hey expla...    522
# 25     65  0.941987  lebron and uncle drew could still mount a come...    285
# 26    141  0.941981        lebron james to javale mcgee... #nbafinals     404
# 27    588  0.941974  let's go to lebron james looking ready for gam...    265
# 28    549  0.941872  we know one thing for sure, lebron james is no...    291
# 29    448  0.940814   should have the finals every year. basketball...    158
#
#        score                                              tweet
# 0   0.249834  this #nbafinals2017 blows  help us #lebron -- ...
# 1   0.249361  i don't hear all the band wagons fans that sup...
# 2   0.247689                   my man durant on #nbafinals2017
# 3   0.247502  why even have a regular season? i knew i didnt...
# 4   0.247421  game #2 who ya'll got? #nbafinals2017#kingjame...
# 5   0.247421  the face of every fans right now. let's go #nb...
# 6   0.246540  the new shaq and kobe is a three point duo in ...
# 7   0.244139  kd is nasty!!!!!!! wow!!!! iggy with the strip...
# 8   0.243686  bron about to put out a diss track about kd if...
# 9   0.243073  what an ending. dubs, baby!!! #nbafinals2017 #...
# 10  0.242941  wow! #kd #kevindurant with the go-ahead 3! #nb...
# 11  0.242350   want this ring and he's playing like it! #nba...
# 12  0.242270  have i ever tweeted about how much i hate slee...
# 13  0.241660   should have to change his name after that exc...
# 14  0.241590  picture of during halftime of the #nbafinals20...
# 15  0.240161     basketball makes fans salty af. #nbafinals2017
# 16  0.240087  these playoffs would have been a lot different...
# 17  0.239126  this #game2 score though ☺️☺️☺️ wow! lol. keep...
# 18  0.239042  say what  up 3-0 #sweep #bayarea #nbafinals201...
# 19  0.239028  a lil bit pressure right now. so it means ther...
# 20  0.238903  "momma there goes that man!" -- marc jackson o...
# 21  0.238571  anyone else catch that fight going down right ...
# 22  0.238442  #meems for the #nbafinals2017 are crazzzzy. th...
# 23  0.238125               #nbafinals2017 game 2. let's get it!
# 24  0.238125                    game 2 #nbafinals2017 let's go
# 25  0.238057  can't downplay the oracle arena crowd and thei...
# 26  0.238049                           game one. #nbafinals2017
# 27  0.238047      what an ending to this game 3. #nbafinals2017
# 28  0.237903  idk what channing fry did to get in the dog ho...
# 29  0.237665                        zara for mvp #nbafinals2017

# %%
print('Event Tweets (travel ban|travelban): ', event_tweet_count('travel ban|travelban'))
A, B = tweets_event_ab_test('travel ban|travelban')
plt.scatter(range(len(A)), A, c = 'g')
plt.scatter(range(len(B)), B, c = 'r')
plt.ylim(-.1,1.2)

# %%
check_score_cluster('travel ban|travelban',.7)

# %%
print('Event Tweets (nationaldonutday): ', event_tweet_count('nationaldonutday'))
A, B = tweets_event_ab_test('nationaldonutday')
plt.scatter(range(len(A)), A, c = 'g')
plt.scatter(range(len(B)), B, c = 'r')
plt.ylim(-.1,1.2)
# Out:
# Event Tweets (nationaldonutday):  528
# A1|A2:  0.998
# B1|B2:  0.816
#
# A1|B1:  0.13
# A2|B2:  0.081
#
# Cosine Similarity Mean of A2 to A1 0.814
# Cosine Similarity Mean of B2 to B1 0.163
# Cosine Similarity Mean of B2 to A1 0.022
#
# Cosine Similarity STD of A2 to A1 0.268
# Cosine Similarity STD of B2 to B1 0.116
# Cosine Similarity STD of B2 to A1 0.027
# (-0.1, 1.2)

# %%
Top_scored_tweets_in_B('nbafinals', n = 300000)

# %%
Top_scored_tweets_in_B('nationaldonutday', n = 300000)

# %%
Top_scored_tweets_in_B('travel Ban|travelban', n = 300000)

# %%
Top_scored_tweets_in_B('paris|climate', n = 300000)
