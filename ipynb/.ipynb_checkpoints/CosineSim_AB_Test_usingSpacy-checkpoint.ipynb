# %%
import pandas as pd
import numpy as np
from spacy.en import English
nlp = English()
import random
from sklearn.metrics.pairwise import cosine_similarity
import math
import matplotlib.pyplot as plt
# %matplotlib inline

import psycopg2 as pg2
import psycopg2.extras as pgex
this_host='34.211.59.66'
this_user='postgres'
this_password='postgres'
conn = pg2.connect(host = this_host, 
                        user = this_user,
                        password = this_password)

sql_select = '''select created_at, tweet_content, cleaned_tweet from tweets;'''

cur = conn.cursor(cursor_factory=pgex.RealDictCursor)
cur.execute(sql_select)
rows = cur.fetchall()
conn.close()
df = pd.DataFrame(rows)

# %%
def event_tweet_count(event):
    event_tweet = df[df['cleaned_tweet'].str.contains((event))]
    return len(event_tweet)

# %%
def tweets_event_ab_test(event, n = 200):
    event_tweet = df[df['cleaned_tweet'].str.contains((event))]
    event_tweet.reset_index(inplace = True)
    
    A_index = list(range(event_tweet.shape[0]))
    random.shuffle(A_index)
    
    n = n
    A1_index = []
    for i in range(n):
        A1_index.append(A_index.pop())
    
    A1 = event_tweet.iloc[A1_index,:]
    A1.reset_index(inplace = True)
    A1_vec = np.array([nlp(i).vector for i in A1['cleaned_tweet']])
    
    A2 = event_tweet.iloc[A_index,:] 
    A2.reset_index(inplace = True)
    A2_vec = np.array([nlp(i).vector for i in A2['cleaned_tweet']])
    non_event_tweet = df[~df['cleaned_tweet'].str.contains(('event'))]
    non_event_tweet.reset_index(inplace = True)
    
    B_index = list(range(non_event_tweet.shape[0]))
    random.shuffle(B_index)
    n = n
    B1_index = []
    for i in range(n):
        B1_index.append(B_index.pop())
    m = A2.shape[0]
    B2_index = []
    for i in range(m):
        B2_index.append(B_index.pop())  
    
    
    B1 = non_event_tweet.iloc[B1_index,:]
    B1.reset_index(inplace = True)
    B1_vec = np.array([nlp(i).vector for i in B1['cleaned_tweet']])
    
    B2 = non_event_tweet.iloc[B2_index,:]
    B2.reset_index(inplace = True)
    B2_vec = np.array([nlp(i).vector for i in B2['cleaned_tweet']])
    
    A1_vec_mean = np.average(A1_vec, axis=0)
    A2_vec_mean = np.average(A2_vec, axis=0)
    B1_vec_mean = np.average(B1_vec, axis=0)
    B2_vec_mean = np.average(B2_vec, axis=0)
    
    a1a2 = cosine_similarity(A1_vec_mean.reshape(1,-1),A2_vec_mean.reshape(1,-1))[0][0]
    b1b2 = cosine_similarity(B2_vec_mean.reshape(1,-1),B1_vec_mean.reshape(1,-1))[0][0]
    a1b1 = cosine_similarity(A1_vec_mean.reshape(1,-1),B1_vec_mean.reshape(1,-1))[0][0]
    a2b2 = cosine_similarity(A2_vec_mean.reshape(1,-1),B2_vec_mean.reshape(1,-1))[0][0]
   
    a2_consim_list = []
    for i in range(min(n,m)):  
        a2_consim_list.append(cosine_similarity(A2_vec[i].reshape(1,-1),A1_vec_mean.reshape(1,-1))[0][0])
    a2_mean = np.mean(np.array(a2_consim_list))
    a2_std = np.std(np.array(a2_consim_list))
    
    b2_consim_list = []
    for i in range(min(n,m)):  
        b2_consim_list.append(cosine_similarity(B2_vec[i].reshape(1,-1),B1_vec_mean.reshape(1,-1))[0][0])
    b2_mean = np.mean(b2_consim_list)
    b2_std = np.std(b2_consim_list)
    
    a1b2_consim_list = []
    for i in range(min(n,m)):  
        a1b2_consim_list.append((cosine_similarity(B2_vec[i].reshape(1,-1),A1_vec_mean.reshape(1,-1))[0][0]))
    a1b2_mean = np.mean(a1b2_consim_list)
    a1b2_std = np.std(a1b2_consim_list)
    
    print('A1|A2: ',a1a2,'\n'
                'B1|B2: ',b1b2, '\n\n'
                'A1|B1: ',a1b1, '\n'
                'A2|B2: ', a2b2, '\n\n'
                'Cosine Similarity Mean of A2 to A1', a2_mean, '\n'
                'Cosine Similarity Mean of B2 to B1', b2_mean, '\n'
                'Cosine Similarity Mean of B2 to A1', a1b2_mean, '\n\n'
                'Cosine Similarity STD of A2 to A1', a2_std, '\n'
                'Cosine Similarity STD of B2 to B1', b2_std, '\n'
                'Cosine Similarity STD of B2 to A1', a1b2_std, '\n'                 
                )
    
    return a2_consim_list, b2_consim_list

# %%
def Top_tweets_in_b(event, n = 200):
    A = df[df['cleaned_tweet'].str.contains((event))]
    A.reset_index(inplace = True)
    A_vec = np.array([nlp(i).vector for i in A['cleaned_tweet']])
    A_vec_mean = np.average(A_vec, axis=0)
    
    
    B = df[~df['cleaned_tweet'].str.contains(('event'))]
    B.reset_index(inplace = True)
    
    B_index = list(range(B.shape[0]))
    random.shuffle(B_index)
    n = n
    B1_index = []
    for i in range(n):
        B1_index.append(B_index.pop())
   
        
    B1 = B.iloc[B1_index,:]
    B1.reset_index(inplace = True)
    B1_vec = np.array([nlp(i).vector for i in B1['cleaned_tweet']])
    
    
    consim_twt_list = []
    for i in range(n):  
        consim_twt_list.append((cosine_similarity(B1_vec[i].reshape(1,-1),A_vec_mean.reshape(1,-1))[0][0], B1['cleaned_tweet'][i]))
    pd.options.display.max_colwidth = 200
    result = pd.DataFrame(consim_twt_list, columns = ['score','tweet'])
    print(result.shape)
    result = result[result['score']>.95]
    result.sort_values('score', axis = 0, ascending = False)
    return result['tweet'].values

# %%
print('Event Tweets (A): ', event_tweet_count('paris|climate'))
A, B = tweets_event_ab_test('paris|climate', n = 200)
plt.scatter(range(len(A)), A, c = 'g')
plt.scatter(range(len(B)), B, c = 'r')
plt.ylim(-.1,1)
# Out:
# Event Tweets (A):  2529
# A1|A2:  0.99946
# B1|B2:  0.999183
#
# A1|B1:  0.975828
# A2|B2:  0.973948
#
# Cosine Similarity Mean of A2 to A1 0.891954
# Cosine Similarity Mean of B2 to B1 0.843705
# Cosine Similarity Mean of B2 to A1 0.825285
#
# Cosine Similarity STD of A2 to A1 0.0902695
# Cosine Similarity STD of B2 to B1 0.140911
# Cosine Similarity STD of B2 to A1 0.137944
# (-0.1, 1)

# %%
print('Event Tweets (A): ', event_tweet_count('nbafinal'))
A, B = tweets_event_ab_test('nbafinals', n = 200)
plt.scatter(range(len(A)), A, c = 'g')
plt.scatter(range(len(B)), B, c = 'r')
plt.ylim(-.1,1.2)
# Out:
# Event Tweets (A):  891
# A1|A2:  0.999089
# B1|B2:  0.999081
#
# A1|B1:  0.947692
# A2|B2:  0.941522
#
# Cosine Similarity Mean of A2 to A1 0.883742
# Cosine Similarity Mean of B2 to B1 0.828579
# Cosine Similarity Mean of B2 to A1 0.79324
#
# Cosine Similarity STD of A2 to A1 0.0681132
# Cosine Similarity STD of B2 to B1 0.159922
# Cosine Similarity STD of B2 to A1 0.138652
# (-0.1, 1.2)

# %%
print('Event Tweets (A): ', event_tweet_count('travel ban|travelban'))
A, B = tweets_event_ab_test('travel ban|travelban', n = 100)
plt.scatter(range(len(A)), A, c = 'g')
plt.scatter(range(len(B)), B, c = 'r')
plt.ylim(-.1,1.2)
# Out:
# Event Tweets (A):  200
# A1|A2:  0.997264
# B1|B2:  0.99504
#
# A1|B1:  0.964011
# A2|B2:  0.960974
#
# Cosine Similarity Mean of A2 to A1 0.905588
# Cosine Similarity Mean of B2 to B1 0.849429
# Cosine Similarity Mean of B2 to A1 0.828775
#
# Cosine Similarity STD of A2 to A1 0.0653177
# Cosine Similarity STD of B2 to B1 0.135647
# Cosine Similarity STD of B2 to A1 0.136235
# (-0.1, 1.2)

# %%
print('Event Tweets (A): ', event_tweet_count('nationaldonutday'))
A, B = tweets_event_ab_test('nationaldonutday', n = 200)
plt.scatter(range(len(A)), A, c = 'g')
plt.scatter(range(len(B)), B, c = 'r')
plt.ylim(-.1,1.2)
# Out:
# Event Tweets (A):  527
# A1|A2:  0.998137
# B1|B2:  0.998347
#
# A1|B1:  0.93367
# A2|B2:  0.91555
#
# Cosine Similarity Mean of A2 to A1 0.873418
# Cosine Similarity Mean of B2 to B1 0.816405
# Cosine Similarity Mean of B2 to A1 0.76242
#
# Cosine Similarity STD of A2 to A1 0.0614424
# Cosine Similarity STD of B2 to B1 0.193445
# Cosine Similarity STD of B2 to A1 0.165231
# (-0.1, 1.2)

# %%
Top_tweets_in_b('paris|climate', n = 15000)
# Out:
# (15000, 2)
# array([ "hey i'm a consumer and like the new site, but this is no way to build revenue and trust with… ",
#        "i'm going to sleep now. wake your asses up &amp; focus on banding together. this is the beginning of the end ofus unl… ",
#        "big sean is a bitch lol. how did you start a beef and go so long without responding to the response that we've forgotten altogether",
#        'trump is more than a stain on our great nation. he is a curse. please hurry, investigators, so we can be rid of him b4 he damages us more.',
#        'and the right has done what? mrs. diss obama repeatedly. how is it obama got more done with a republican congress… ',
#        ' yeah, wtf is up with that? come on matt - we expect better of our assemblymembers… ',
#        "last night's closing reception was a very good exercise in public speaking. it pays to have memorized what your vision really is.",
#        "dinner with the fam! with all of us spread out, it doesn't happen often. #itsagoodnight ",
#        "ok wonder woman. it's a great film that i'm curious to see but the opinions are of those you don't like it",
#        "God really has his timing for everything. He's always right on time with the things I ask for.",
#        "i think trump won to raise awareness about how this world really is in 2017. nothing's changed. gonna get ugly before it gets pretty!!",
#        ' hes too stupid to know they have gun control, he is too stupid to wipe his own backside why on earth is he still in office',
#        "associating with genuinely good energy &amp; people is the standard. and, like a tree, you will know them by their 'fru… ",
#        'why were we forced to play the recorder in elementary? how was that suppose to prepare me for all this real life shit ...',
#        'do not be conformed to this world, but be transformed by the renewal of your mind...',
#        " it amazes me the wealthy don't take over climate change. with all the terror there's not a priority for it",
#        "is not using 8 bar intros really that hot a take? i know a bunch of other djs who don't fux wit intros at all.",
#        'sensible minds of all races need to unite now. because this is the last stop right here.',
#        'same goes for guys, they be goin through it just as much ',
#        "i don't do much in the way of #ff anymore, but boy howdy check out this twitterer: ",
#        'why do we hide the way we feel from others? is it the fear of rejection?',
#        "i wonder what people that aren't from los angeles think about us when they visit for the first time.",
#        'hey, continuing to tear it up in recruiting. so excited for the future of the program! 🤘🏼 ',
#        "on one of the nights before you leave, it's going to be special. because in my heart, you're the most special person in my life.",
#        'stuck in a van for the next 5hrs &amp; just heard putin telling us all "don\'t worry, be happy." followed by song. we\'re doomed. crying. again.',
#        "yeah but they for sure could've found another board. a whole damn boat sank .. you mean to tell me that's the only… ",
#        'if we all go within there will be less ego- made problems on this earth.',
#        'happy #worldenvironmentday! of all the things you can do to help the planet, cutting back on… ',
#        'how does one stay on and not see spoiler alerts from #wwdc2017? be on a list timeline (beer and coffee are what i’m on.',
#        'arlie hochschild is an important voice for getting progressives back to what will win back rural people. ',
#        "oc! this sunday is the new saturday so let's party like there's no monday. ",
#        "lasorda's trade &amp; he didn't know the rule about trading a guy with a contract, so they had to renegotiate with shaw or lose to free agency.",
#        'when the votes are there to impeach, i\'ll bet he tweets, "yeah, we colluded, and putin had the goods on me. it\'s not like no one knew!"',
#        'headlights that get brighter the harder you are breaking would stop a lot of wrecks.',
#        'my heart goes out to not just london. but to every single person who is more afraid now than ever. this affects everyone.',
#        "i mean, it's really just trump withdrawing from the #parisagreement - the united states are staying united with the rest of the world.",
#        'i\'m such a "wait don\'t get out of the car yet, this is a good song" type of person',
#        "what a mentally off thing to say and do. we support our allies and those in need during tragedy. we don't insult an… ",
#        'and trump fucking blames the democrats? we live in an alternative dimension, this man is a fucking lunatic. "negotiate a better deal?" no!',
#        'yes, my apricots are just the best but late rains made them a disaster.. next year will be good.. ',
#        "words cannot explain how sad my heart is that trump has betrayed our earth. it's not over, we just have one helluva fight ahead ",
#        'did i miss a revised memo announcing that the antichrist would come in the form of a \U0001f921? or, you know, s complete idiot?. ',
#        'still possible to cross up, but slightly stricter timing and definitely less ambiguous for the opponent. now, you can only really use the oh',
#        "in the end, no one will be here for me other than me. so don't get it twisted, i will be on the top waving down to all those doubters. ",
#        'i’d never go into a position or seek out a position with the pretense of wanting something more than just professional. it’s inappropriate.',
#        " if you liken the consumption of pizza to that of having a habitable planet then yes, that's climate science.",
#        'there definitely is a reason. thank you for this. this is a low point in our history. dt goes down as the absolute… ',
#        'spent this week on 2nd shift training the new guy. def not use to the schedule anymore . only good thing is in n out for lunch today ',
#        " this one is off brand but it's from us. claim it can hold to 25. not sure what the weight of the ronin + red is",
#        'if ever there were a place to find fairies and elves, this might be it... . . #california… ',
#        "people fail to realize my team is my team, if they fucking with you it's all based on me once i fuck off they do to. ",
#        "the is a joke. so many things wrong with it. can't say all of them in 140 characters.",
#        " i'm not sure if you've addressed this, but listening to the latest pod and the people asking why you got so mad and (cont)",
#        "i did my small part to defend la's intimate theaters today. if we stay home, the bad guys win by default. #lathtr",
#        "not everybody's reality is the same as yours, be conscious of that.",
#        " they aren't fear-mongers and thats big difference b.w. you and the rest of the developed countries leaders.",
#        'it\'s always bugs me when people say "graduating high school isn\'t that important, it\'s expected." yeah maybe for you, but not everyone',
#        'so some guy gave and i $20 each to cut in front of us in line at the brewery, then talked to us about sharks. it was worth. 🤑',
#        ' reminds me of a funny quote: "given enough time, hydrogen starts to wonder where it came from, and… ',
#        " i've had to stop expending the energy of explaining this, sadly. i instead link a grea… ",
#        " you can trade it back for full value if within a certain time. i think it's 15 days.",
#        '. wants you to experience the music and wonder of the enter now! #iheartaustin ',
#        "just found out denny's delivers now. that's a game changer right there, might just have to order me some rn",
#        'the only way to make sense out of change is to plunge into it, move with it, and join the dance. - alan watts ',
#        "it's a liberating feeling not be paralyzed by how quickly you can get on/off an airplane. does each seat detach and… ",
#        'set the tone for the day. start it with the belief that it will be the best day ever, and it just might be.',
#        'can time ever stop? not that high school went by fast, but i can remember a lot and think back on it.',
#        "look how beautiful and round that is. our earth is amazing, we need to protect it from it's only natural enemy. con… ",
#        'rev. michael beckwith always tells me about myself in his messages in ways that hit home &amp; confirm what my next steps are...',
#        "this is really annoying. what's the point of advance stop lines if people don't respect them? ",
#        "this is the type of person who is a mockery of people who are actually truly going through shit &amp; it's revolting that she gets away with it",
#        " are you the only company on the planet that doesn't monitor social media? that explains a lot #youjustdon'tcare",
#        'lebron may be a lot of things but i know what he is not: whatever hateful thing was scrawled on his gate. no man or woman is. end racism.',
#        ' the one thing i can say for cards is the outcomes (vapid cynicism over vapid idealism) tend to track more with reality.',
#        'another tragedy in london. there are just too many people for the security services to watch. each one takes scores of people #londonbridge',
#        'my prayers goes to those that work in that company, we need to always keep our eyes open for any that is not normal. ',
#        ' if, in a sea of male privilege, you hear women saying "we want a space just for us tonight" &amp;… ',
#        "maya angelou wrote, you may trod me in the very dirt.but still like dust i'll rise . maya angelou still speaks for all of us.",
#        ' no i don’t. just see it in the bg while i’m working that theres a new tweet in my feed!',
#        'i still have faith in twitter, it was once a cool place to consistently talk boxing, joke around make stupid hashtags and make fun of each..',
#        "the fiction issue of the new yorker is finally here! it's 10:30 and i might just call it a day… ",
#        'my &lt;3 is with you, #london for every idiot who uses these situations 2 further their own agendas, there are thousands who truly care.',
#        " naw it didn't work lol. was thinking with the wrong head, or whatever the saying is.",
#        "#lastword #maddow if it weren't for the work of our journalists, we'd still be hearing about crowd size.",
#        "when it comes to #custexp, i must say = worst. just take their ios #app as an example, can't do simple things.… ",
#        "we should be asking our mp's, senators, representatives in every country what serious plan they have in place to keep us safe....",
#        "knowing what it feels like to be satisfied isn't same as being full. it takes our brain 20 minutes to get the messa… ",
#        "nothing is better than chilling with you. tell me your secrets and what's on your mind. our best kind of dates. ❤️",
#        'all i could think about after taking this picture is "faith can move mountains" ',
#        " let's start over. you suggested he'd be able to assume dictator-like powers bc of his popular… ",
#        " why didn't you refute al gores employment numbers!? make fun of him but he's not wrong and coal ain't producing those job #s",
#        'why do guys find it necessary to comment on the amount of makeup someone is wearing when it has 0% effect on their… ',
#        'some supervisors need to stop being so demanding and understanding. the only thing out their mouth is an accusation. speak and communicate.',
#        ' i totally agree with your analysis on cnn today. trump is a narcissistic sociopath and sees the "world according to trump."',
#        '"it\'s very bad luck to draw the line, on the night before the world ends. we can draw the line some other time." ~ x',
#        "lol. when will white people learn it's never ok to use the n' word? under any context. ",
#        ' lol no i feel you, people have a persecution complex when it comes to the media for sure, &amp; a lot of the criticism is justified.',
#        'right now bing hit with every possible drug dealer. deal just do this. on my nom phones and nets. no to all it cost to much to work',
#        ' of course we are able to hold several topics in mind right ? well, some of us anyway',
#        'being #36 does not give children in the us a strong foundation for a good life. shame on all of us #savethechildren ',
#        "2019 pj fuller was put on god's earth to do many things in life..but the 1 thing he's seem to perfect at an early age is getting buckets!",
#        "let's not forget needs our help even if we're not from ga. #flipthe6th ",
#        "trump is punking all of the republican. they r afraid ..of him.they can't even speak to each. the mess an lies come from top",
#        " waiting for you to step down from dt's advisory board since he left the #parisagreement. otherwise you… ",
#        "it's been a long few weeks and now that the dust is settling it feels more real than ever before. one day at a time i guess",
#        " same nolasco, different day. 2 more home runs given up by halo pitching. that's how you do it",
#        "aww the cooks at the food court already know me, once they see me they start making my food so it's ready by the time i pay 🤗",
#        'i knew would be bad for our country, but withdrawing from the means the planet gets to be worse too🤗 🔥🌎🔥',
#        " sir i'm kind of concerned that we are in the height of hurricane season and there's no fema director. why? #toolatekills",
#        "i get that was just trying to be funny, but he's old enough to know that the n-word should not be used, period. #satchat",
#        "when putin asserts hacking the american election was so simple even a 3 year-old could plan it... one has to assume he's referring to trump.",
#        " 3/3 on a few occassions attitude is necessary. but not on every occassion. and certainly not with your 'friends'.",
#        ' think they better cause you stuck in your alcoholic ways. fuck it we still out here having a good time ',
#        ' but yeah, you are right in that something has to be done. in a big way.',
#        " hello ... i believe being ready for all situations none of those situations have happened to me yet but that's not the point",
#        'thank god for those researchers bringing to light this unknown information, now that we have it we can end racism f… ',
#        'we saw the cast of absolutely kill it on our walkthrough just now. a perfect job. ',
#        '#sb562 is a must. we need it... we need to show this country how to fucking life. #tytlive',
#        ' how are you, john? relishing time back in australia with family, i trust. i look fwd to hearing more about your indie film.x',
#        ' damn, this one of those "it\'s me " tweets gio? i knew you was on them ped\'s.',
#        " hi, will you be getting more editions of the dr. who complete history? i'm interested in more issues from the first 4 doctors. thx.",
#        "Why can't everyone in this world be kind to stray animals? Kindness is free and doesn't cost a thing! ",
#        "ederson for €40million after pep signed bravo last season is bonkers! imagine how much we'd have to pay for cech or courtois in this market.",
#        "in the streaming age every song doesn't have to be a super banger or high work of art once the catalog is accrued it just keeps going",
#        "i'm trying really hard not to overreact, but #juneweddings on is the greatest thing that's ever ha… ",
#        "i hate what's going on in the city of new orleans ...we so selfish an don't even know it",
#        'i want to go to the rodeo and then go again, just so i can say, "this isn\'t my first rodeo."',
#        'from the "i simply don\'t have two shits to give about ethics dept." of the trump administration. ',
#        'nothing is fun when you have to do it on your own. says the person who gets anxiety regarding being alone. life is fun.',
#        "feeling work is healing work. why? because there's a litany of emotions you've feared and run from your entire life. it's left you hollow.",
#        " of course i would, but again, that's not what we were debating. as a separate and distinct argument, i agree with it.",
#        "ivanka, if you have as much sway with your dad on lgbtq issues as you did on climate, immigration &amp; women's rights, think we'll pass, kthx.",
#        "when you going through the gate and the ma flirting with you but can't get your number bc it's not professional \U0001f926\u200d♀️",
#        "was it really that deep to send them the situation ? bshzkjzu. if something did occur there's plenty of tuitions that can show proof. ugh ",
#        "there's a group of #49er fans that will come into your mentions anytime you post anything positive about kaepernick they are annoying",
#        "if you can't tell me how many genders there are or when human life begins, i'll kindly pass on your theories about the weather next century.",
#        'wait, reseda is a real place? i thought they just made that up for karate kid. #overheardatthisbar',
#        ' very surprised that the potus and anybody in his administration even new the alphabet. tomorrow maybe they… ',
#        'i try to be an optimist and stay positive all the time. but the pessimists tend to bring me down.',
#        "why have a gay pride month when you're a normal person just like the rest of us? ",
#        'such good people in this world. to anyone/everyone who has ever helped me or believed in our collaborative vision, you are everything. ',
#        " declared that he admires a developing nation's coal industry as something we should be striving for?! talk about leading from behind!",
#        " when the other nations see that it weakens they're respect for us. although i see they're beginning… ",
#        'when the money talks, what is there to sayy?',
#        ' i completely oppose your decision to abandon the you just put our future in peril with no plan. again. sad',
#        'was tempted to get the hero black but i was like chill john... you have the 4 and it will get the job done for this trip. #thestruggletho ',
#        " this is why i can't stand religious! if you believe this life is temporary, then you ultimately have no obligation to fix this life",
#        ' i think it was right...and he intends to renegotiate our membership and go back in.',
#        "seriously, twitter? national donut day? that's the most important thing you see going on around you right now?",
#        " i'm not going to lie, it's hard in this day and age streaming in the community. you gotta… ",
#        "the perfect word to describe me in spanish is pelionera, it basically means bitch who always be tryna fight everyone, it's because i'm hood",
#        " determine from what you've seen so far. the world is never ended tomorrow. ",
#        "can't we just have one day, just one day, when donald doesn't do something beyond inane. the guy is an idiot, completely clueless.",
#        'sure why not blame for trump pulling out of the paris agreement. what happened to you? ',
#        'always worried when folks say we should participate in oppressive practices because so &amp; so used to be an activist. no free passes. be real.',
#        'think the gop will do anything to stop trump and his dangerous policies? neither do we. our only hope is to flip t… ',
#        " i worked a campaign in florida. no lines are preferable, especially if it's because of vbms or early voting. ",
#        "been muting climate change deniers all day, don't give them the satisfaction of complaining about a block. #climatechangeisreal",
#        "well part people used to make fun of me for it but fuck it it's the truth",
#        ' the promise of bbses played a lot into it too. but i know exactly what you mean by ocean separated pen p… ',
#        'so now when future generations ask what the inspiration for the movie was, we can point to this day. co… ',
#        "watching #houseofcardss5 on is unsettling when its extreme reality isn't so far away from our grave new world.",
#        "we need a health system that's #forourpatients! i won't accept reform that puts millions at risk of losing coverage. ",
#        " i don't think so. it's summer so a lot of people are traveling. etc. also, the resist march is next we… ",
#        "what's happening is gotham is just terrible, who would have known. why is gordon still in charge? make gotham great again - dt #batmansdms",
#        " joe msnbc's hand is so far up your ass they work you like a puppet. you are a pathetic excuse for a journalist.",
#        ' you are not our president. impeach, resign or darn well will not get a 2nd term. narcissistic hate mongering trash.',
#        '#america is a melting pot. trump is not a racist. we need proper vetting. are you coming here to be part of melting pot or islamify america❓',
#        '"when long term goals clash with immediate demands on your time, stop, think: there are no quick, ride it out." -- paul ebeling',
#        ' have you seen the new wonder woman? going today to check now. ',
#        'everybody is a genius. but if you judge a fish by its ability to climb a tree, it will live its whole life believing that it is stupid',
#        "that's an interesting theory, but i think it's about minimizing the amount of human-caused #climatechange, like the… ",
#        " that's what's being investigated. you do realize that the children of former presidents should be ma… ",
#        'Marketing is a replacement for reputation where the seller rather than fellow buyers get to tell you how great they are.',
#        "it's almost like the dark forces of the world think they can win? but i read the end; satan and his ilk loose. fear… ",
#        ' i follow them but i cannot stand the "pay for news" model. there is so much free news out there, why a pay wall?',
#        ' it\'s really great looking back and realizing all the "best practices" he pushed on us are absolute garbage.',
#        "we're being told how much the wwc matters, when at the same time poc are under near constant assault. guess what? we've noticed!!",
#        "the u.k. surveillance state has clearly worked wonders for security so i'm sure these new plans will be just as effective. #sarcasm",
#        ' terminatr: grindr and tindr, but for murderous cyborgs think about it this could be huge',
#        'it\'s my first time lining up at a starbucks in the us. how do i say "grande"? help, i\'m an amateur! #heidisjtrip',
#        " what is going on? we've been circling the runways for over an hour waiting for a gate. it simply can't be that crowded.",
#        "you my boy man, we go back but we've gotten closer this year and it's always a pleasure hangin' with you. we got many memories &amp; mre 2 cm",
#        "lmfao this is so fucking frustrating :-)))) i hate doing something and finding out it didn't need to be done in the first place",
#        "just in case you weren't aware: the everyone suddenly has an opinion about isn't free. from 2016: ",
#        "as matter of principle if u can't see foolishness of paris accord then good riddance-now go fly away-making big car… ",
#        'i stand for a better world. it starts with one person! is that you? ',
#        'this years all white is a celebration of embracing the accomplishments we are accomplishing you know proud to be melanin. we control culture',
#        "president trump you should get behind this. we have all been waiting for this. it's huge for humanity… ",
#        "#yourenotwrongbut i wouldn't make a notch in your headboard over it either.",
#        "also, for some reason, the only choreo they could think of is just having the dogs kind of shuffle left and right. it's very bad. #pupstar",
#        'i tell u, if any repug calls me a covfefe i will step on their dicks in the parking lot. believe me! &amp; i know so much mor than the generals👐',
#        "just in case you weren't aware: the everyone suddenly has an opinion isn't free. this is from 2016: ",
#        "i see people outside playing volleyball on the beach and i can't help but wonder if they know that it's the cup?! \U0001f926\u200d♀️ #stanleycup #gopreds",
#        "my god, so sorry you lost sleep over something that you shouldn't have even considered saying in the first place, m… ",
#        'anyone hear a word about #kathygriffin out of anderson coopers mouth? i decided not to watch cnn anymore due to chilling effect of firing.',
#        'not going to tolerate shit from anyone anymore. either you with me or not. if you have a problem than address it, if not than drop me.',
#        "i don't have this bank, but here's a good #starbucks deal through wednesday if you have/use… ",
#        'is it bad that after seeing wonder woman i want to be her for halloween for the rest of my life?',
#        "sometimes, out of pain &amp; wanting more support, you say things that hurt the 1 you love. i'm not too big to apologize when i've been wrong.",
#        " we are acomplishing nothing. 2 people with phds have told you it's real.… ",
#        ' is there a link anywhere or even the text of the motion? i’m coming up short finding anything. and w… ',
#        "i can't believe i have to leave right now for work. so ironic that working in soccer is responsible for me missing soccer #uclfinal",
#        'slavecatcher anson now seems to be basically the sidekick to kano. the movie is absolutely not going to examine this. #pupstar #writing',
#        "vice president pence, again you're on the wrong side of the issue about climate change. being governor of indiana you're stuck in the snow",
#        'octopus pie has been part of my day for almost a decade. sorry to see it come to an end, but thank you fo… ',
#        'leaving the #parisagreement is going to not only ruin the economy but the world in the near future.. climate change is not a "hoax"',
#        'with regards to the n-word, joan crawford said it best: "the answer to feeling unattractive isn\'t to make yourself even uglier." #feudfx',
#        " if you think you are going to heaven, you're in for a major surprise. #readyourbible",
#        "-also, if you do everything by the book you're going to fail. i've seen it. -just for ole times sake, fuck men",
#        ' you have to be willing. the only way to get to success, is starting with the willingness to try.',
#        "i may dip back for a minute, but it's only to recharge so i can do what needs to be done. cause... it will get done in time.",
#        'it\'s silly that "belief" in global warming is even a thing. more americans are "believing"1+1=2 than ever before!',
#        'i should probably just stop watching #twinpeaks now. nothing is going to top seeing someone bludgeoned into submission with a flute. #s2e15',
#        ' hey, quick question...how much does the us pollute compared to other nations? also, your info is wrong… ',
#        "change is coming in our weather. here's what to expect #cawx ",
#        " your rage isn't reason just emotional! this is a bad deal for the usa! the results are negligible but… ",
#        'why do guys think it\'s okay to flirt &amp; "get at" the friends of a girl they used to rock with. y\'all are trifling.',
#        'dying 5 times was enough for me and them until i reach the final one. death is something that has no time limit so when and where is choice.',
#        ' sorry... this guy should never see the light of day again. this is beyond jealously or rage. #tytlive',
#        " that's why you try it on ahead of time.",
#        "you know it's bad for mjrica when the chinese are pushing for new innovation and resource efficiency ahead of us. p… ",
#        "agreed! if you're saying horrible racist things in your private life, it's going to come out in your public life. t… ",
#        "there's no such thing as bad press. kathy griffin just moved up to the c list...",
#        'everything happens in 3s... and i got the worst of it today. what did i do to deserve this?!',
#        ' pulling out of #parisagreement is a blow to the environment and a bad deal all around.',
#        " oh no there are reasons. it's just hard to find fans like yourself who will not show boat their team when they're good",
#        "you know it's unpopular and bad for business when goldman sachs and exxon mobil even say it's a bad idea. #parisaccord",
#        " it's really kind of incredible. across the board. seeing it for a third time on sunday. #wonderwoman",
#        ' and? not sure what your point is, they handled it very well.',
#        'people of color have little to no say in this administration with helping to decide the future of a planet we inhab… ',
#        'is it just me or is calling to cancel a line like trying to learn quantum physics. 4 days later, i keep getting redirected 😕😐😑',
#        "we debuted yasir shah against india in wc knowing india plays spin so well, and it didn't work. now trying shadab in place of faheem ashraf",
#        "#pressbriefing 45 can't even decide if santa is real. how can he decide on something proven in science?",
#        ' screening for travel in and out of usa is a must for citizens safety. however, hope his plan does not over react to total restriction',
#        '"it is a tweet. what else would it be? a bowl of petunias?" this is actually the best television i\'ve ever seen never sleeping #travelban',
#        'why is the bible influencing our politics, anyway? the founding fathers used it only as a prop. ',
#        " it's true, most people don't remember the names of the 1%.",
#        " the obamas just dropped $8m on their new dc home. they don't seem worried, which is reassuring. they know it's going to be okay?",
#        "this man is in 2040...and i know y'all see that arsenal, he ready for any thing on mommas ",
#        "if you haven't seen wonder woman yet you are totally missing out. easily one of the best superhero movies out there. #wonderwoman",
#        "it's me. the one you should believe in.",
#        "losing too many homies to the streets &amp; even for no reason at all just shooting at anybody. y'all need to be safe out there flyhigh bro ❤️",
#        "btw, don't confuse my analysis of the situation for apathy. i'm not okay with sense 8 getting the axe. and i just started season 2...",
#        'lol at all the people justifying trump\'s actions because the #parisagreement "didn\'t have teeth" that has nothing to do with his decision.',
#        'how much is your vote worth? are we seeing a false flag to get a rally round the leader moment? ',
#        "even i know what obama care is and the idea about it and i'm 15, while the vp makes an incorrect comment about obam… ",
#        "not one to wish any negativity towards any athlete but judge is no mike trout. hmu in 5 years &amp; let's see what he's… ",
#        ' lol tomi way to use 1 voice to describe an entire movement and misdirect from the issue at hand. still… ',
#        "#leadingcauseofdeath let that sink in. it's really mass suicide if you think about it. ",
#        "decided 2 smile. count my blessings (couldn't count them all). and changed my perspective by focusing on what really matters. the rest is eh",
#        ' try not to talk over people, it is rude and it also shows how desperate you are to get that message out there which is fake',
#        'happy month of june! we have the best month ahead of us with so much planned in the life of our church. we cannot c… ',
#        "should we go low with them it's hard not to is old news she was forgiven in the daily scandal… ",
#        'if we put all these people in a round room and asked them to find a corner, would they stay there forever? ',
#        '"those who fail in life are the ones who make the most excuses. avoid them at at all cost once you learn that." -- paul ebeling',
#        "noneeee of that. i'm just a good friend. scratch that, a real friend. anyone can listen to your struggles, but who'… ",
#        "y'all put too much on god to do for you. how you praying for everything? car won't start? get it fixed. prayer is not a magic wand.",
#        'trump golfing today sends a very strong message to the uk and the world: "i don\'t care about you."',
#        "the more credibility we have with someone, the more we are trusted. it's not until we lose… ",
#        'fighting climate change is not the enemy of job creation. just look at the and for proof. ',
#        " nixon did open relations with china and start the epa. if only he hadn't been such a moral sleaze.",
#        " it seems that you're doing you best to live up to patrice's legacy. good luck and… ",
#        "hot take. not sure it's good for anyone except the warriors and their fans #nbafinals ",
#        "can't stand either of one these teams but it's pretty clear who the better team is. i mean we all saw this coming. #nbafinals",
#        "even the most in-love guy will check out a beautiful human walking by, and girl, u will too. so don't trip☺️",
#        "how do you compare someone to be greater when they're not even the 1st option in crunch time ... #kobevslebron",
#        " you're really getting mixed on message. one day it's a ban. one day it's not.",
#        'gets to luigis. mark: shaughn we have a mission for you. you are going to breakout our scanner from the guardians.',
#        "screw a (rip harris) / my callsheet for tomorrow is stacked with names! can't say who or what for, because it's just that legit.",
#        'now that has apologized. we accept it, and move on...with the hope that we never have to go through this again.',
#        'the fact that i have to take an uber to the airport cuz "no one" can take me  #fakes',
#        'i wish social media would send you a disclaimer before every post that says "you know none really cares about this right?" #stopbitching',
#        "today's show is the example of why i advocated long ago for this journalist to have her on show. should get an emmy for this! #amjoy",
#        "it's exciting that if we pull out of paris treaty, we'll be in the same company as syria and nicaragua",
#        ' jake. first that is a dumb question. the climate has been changing for millions of years. the question… ',
#        "earth is a mess can you hurry up and launch a mission to find a new planet for us? and let's keep kim jong-un, putin, etc. out thanks.",
#        "it sounds silly to those who don't constantly experience it, but that is legit one of the reasons i insist on walking instead of ubering",
#        " c'mon out to california and see the usa's most economically successful state, potus! or, just hole up in your rust belt rallies",
#        ' you get me! starving artists is a real thing. we have little to start with yet everything costs an arm a… ',
#        "there is no america to make great again when there's not an environment you idiot ",
#        "but props to those that keep dancing i can't live with that uncertainty in the future, takes grit to stay in the game and make it your life",
#        " go cry a/b girls taking your toys somewhere else, trollboy. the grownups are talking now and it's reality time.",
#        " you're right - trump was elected to represent pittsburgh. too bad he is not doing so with regard to climate change.",
#        'the official britney spears world tour start time in tokyo, japan tonight is 5pm. it seems a bit early to us, but that is the custom there.',
#        "why is it that when shark week arrives, women get extra ignorant and it's all week and when you ignore them they get all pissed off #byeb",
#        'the last day of class is a special one. the silence is broken so everyone can bitch to each other about what happened throughout the quarter',
#        " yeah and healthcare looks like it has a bright future in the usa as well, i'm sure his approval ratings would agree.",
#        "it would appear trump is part of russia's plan for world domination. all putin thinks he has to do is sit and wait it out",
#        'and said, "i will show you and take my support for climate accord &amp; go home. see how you like it w… ',
#        '#britishpolice know these guys! worldwide, all people of this kind "on the radar" should jailed 4 life or deported! ',
#        'the majority of americans want us to stay signed onto the paris climate agreement &amp; take responsibility for our actions like a grown up.',
#        "how is it not legal to watch puppy videos while sitting in traffic seriously it's the only thing that keeps me from killing people out here",
#        ' again you slap the disabled in the face. it is coelenterates like you who drove voters in pa, mi and oh to vote trump.',
#        " well maybe free agency will be good with her, but if the seahawks go with her instead of kaepernick i'll be disappointed.",
#        'from a realist pov, i understand trump having to cut deals with the mobbed-up construction industry, but he also cheated contractors!',
#        " if he's third best on the court, isn't it a mystery how he's always ending up with the higher +/-, since 2013?",
#        "anyway, 30 seconds after that i hear shouting behind me. multiple people just hollering in the distance. i have a good idea what's coming.",
#        ' sad but true. or more to the point, the ec did.',
#        " go ahead and do it. doesn't have to be a wave, stand out. ",
#        'sometimes the bad things that happen in our lifes are to put us directly on the path for best things to ever happen to us...',
#        "it was just so good!! make sure you go see - it's the dc film us nerds wanted and the mass market… ",
#        " fair re models, but the fact that dirty manufacturing and energy is making the world physically sicker isn't much of a debate.",
#        ' ah, yeah. i\'ll never understand it either. the only thing that legacy has going for it is "better"… ',
#        "although it's controversial ima just say if you really pay attention the paris deal was actually complete shit and horrible for our country",
#        ' how is it possible to get a tweet from you with 3.3 ml followers?i would love it. ♥️',
#        "good advice. take the time to listen  and look  around to learn what's working already. #socialmediamarketing… ",
#        "i can think of another time when 'going within' to claim victory put me on the road to triumph!  #spiritlead… ",
#        ' but seriously, #it✨would be nice to see u in the future… ',
#        "steph just had lbj on toast, not sure that's wise, watch out for an answer from the king! #nbafinals",
#        'wrestling is evolving and the new generation is just better than the older. otherwise we have failed as a craft right? just admit it.',
#        '“it’s not about deserve; it’s about what you believe. and i believe in love. … only love will truly save the world.” #wonderwoman',
#        'two emotions right now. #mad and #scared. "cherish the people you #love, you never know what\'s going to happen, #life is short"',
#        "coming to the end of the semester, it looks like i have solid b's in all my classes &amp; there's not much that can bring em down or bump em up",
#        'you know on a change of subject, when you have a friend that knows how to fix peoples brains, they can tell you whose been fucking around in',
#        "no. what matters most is how much you #love and what's your motivation. no to masochism. :-) ",
#        "everything i do is for the benefit of my future, because if you do things that don't benefit or grow you as a person you're wasting time.",
#        'what are you doing today in dtla? we are making #it happen. whatever your "it" is #justdoit and… ',
#        'day one of the startup working out of an office. always weird to start a new thing. hopefully it will be good.',
#        'london. i have no words. everyone please stay safe. the world can be a scary place, but we can get through anything as one.',
#        "well i guess the liberals will want to light candles and put flowers down all over the place. they really don't get the fact we are at war!",
#        "y'all know y'all can take the words off of your snaps, right? shit be unrelated af. ",
#        " because of we don't have much of a left push against saudi support here #corporatist #warmongers"], dtype=object)

# %%
Top_tweets_in_b('nationaldonutday', n = 15000)
# Out:
# (15000, 2)
# array([ 'every single day i spend with them is the best day ever! #family #qualitytime #familynight #truelove #santamonica… ',
#        'a dame that knows the ropes isn’t likely to get tied up. - #maewest #womeninhorror #actress #photography #g113 ',
#        "there's #never #been a #terroristattack at a #nudist #colony. nudists aren't armed. they're nude. draw your own con… ",
#        'what an honor to lead meditation this am thank you to everyone who showed up! #greentreeyogala #meditate #namaste #friends',
#        'it never gets old with this view ... #laketahoe #outsideisfree #blackandwhite @ inspiration point ',
#        'why yes, of course i need this $448 tote! ⚾️ #inmytotedreams #dooneyandbourke #dodgers… ',
#        '#betweekend gone be #lit the #teamsmokegoodeatgood way  come party  june 25th!! with special… ',
#        "it's about to go down! #lhsgrad2017 #gvusdshares ",
#        'my #family like #toyota my #wife picking me up to have #lunch together she has a #2008 #toyota… ',
#        'now its me and this pupper waiting in this long ass line. #saturdayclinic #doggos #puppers ',
#        "first time ever at the #hollywoodbowl and i'll be working it! #lookatgod #soldout #nkotb… ",
#        '#mommadurant though... giving it to #sas get yo entire life!! #therealmvp ',
#        'a sight like this will sure make you slow down and take a deep breath! #mthood #oregon #wilderness #volcano #skiing… ',
#        'just like latam\'s rulers, give it to my friends by "privatizing it" #stuffdictatorsdo #ignoranceprevails #repost ',
#        "this is the best thing i've seen all day #masterofpotus #metallitrump #trumptallica #goat… ",
#        '#monday #motivation - dear #cannabis #industry... - it\'s time to "shit... or get off the… ',
#        '#sheadiamond\'s song "i am her" will have you feeling all the feels. #trans #lgbtq #queer #queer #pridemonth ',
#        'had a fantabulous time at the #totalpackagetour last night. #boyz2men #paulaabdul #nkotb were all awesome!… ',
#        'on a sunday ? can let it stop me.. keep it movin.. #work #hollywood #sunday #view #upinthehills ',
#        " steven i know it's you! tweet my sign dangit. #stephen #yeahiwentthere",
#        " it'd be awesome if there was a gif of the #julexis hug!! #gh #promotewhatworks #julexisrebuild",
#        'when you just had to have the pin. #beautyandthebeast #funtimes #workflow @ burbank, california ',
#        'a different experience is coming soon! wait for it! #silverlake #la #losangeles #westcoast… ',
#        '#hennabracelet  thank you for a great #weekend full of art this #junegloom this #henna we did… ',
#        "want to work at city of hope? we're #hiring in #losangeles, ca! click for details: #phd #postdoc #cityofhope #job",
#        '#europe is the frog, #islam is the scorpion.. we all know how this story ends. #london #londonbridgeattack #londonbridge',
#        'jacqueline rogers, vintner - i like the way that sounds! #auctionnapa #anv17 #wdcru… ',
#        '#sorry had to #repost cause there were things in the #mix #pissing me #off so #tweaked it… ',
#        '3 tvs really came in handy today. lots going on at the same time! #launchday #crs11… '], dtype=object)
