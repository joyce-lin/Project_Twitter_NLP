# %%
#!pip install redis
#!pip install wordcloud
import pandas as pd
import numpy as np
from datetime import datetime, timedelta
from sklearn.decomposition import TruncatedSVD
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.pipeline import Pipeline
import random
from sklearn.metrics.pairwise import cosine_similarity
import math
from tqdm import tqdm
from dateutil import tz
import matplotlib.pyplot as plt
# %matplotlib inline
from wordcloud import WordCloud, STOPWORDS
import pickle
import redis
import os,sys,inspect
currentdir = os.path.dirname(os.path.abspath(inspect.getfile(inspect.currentframe())))
parentdir = os.path.dirname(currentdir)
sys.path.insert(0,parentdir)
from lib.conn_postgres import connect_to_postgres as conpg

# %%
conn, cur = conpg(location = 'postgres')

# %%
conn, cur = conpg(location = 'postgres')
sql_select = '''select created_at, location, tweet_content, cleaned_tweet, hashtags, date, time, date_time  
                from tweets where (date_time >= NOW() - '24 hour'::INTERVAL) and hashtags is not null and hashtags != 'None';'''
cur.execute(sql_select)
rows = cur.fetchall()
conn.close()
df = pd.DataFrame(rows)
df.reset_index(inplace = True)
df['created_datetime'] = pd.to_datetime(df['created_at'])
df['year'] = df.created_datetime.apply(lambda x: x.year)
df['month'] = df.created_datetime.apply(lambda x: x.month)
df['day'] = df.created_datetime.apply(lambda x: x.day)
df['hour'] = df.created_datetime.apply(lambda x: x.hour)
len(df)
# Out:
# 8145

# %%
df = df[~df['hashtags'].str.contains('amp')]
df = df[~df['hashtags'].str.contains('job|hiring|sales|retail|clerical')]
df = df[~df['hashtags'].str.contains('dallas|plano|irving|richardson|garland|allen|odessa|midland|sanfrancisco|losangeles|irvine|garland')]

# %%
len(df)
# Out:
# 6705

# %%
df[~df['location'].str.contains('.ca|california')][~df['location'].str.contains('.tx|texas')]
# Out:
# /opt/conda/lib/python3.5/site-packages/ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#       index                                      cleaned_tweet  \
# 30       30  great nite shoulda been there!  #friends #weho...
# 57       57  well, that was quite some show! #playstatione3...
# 129     129  the ringing of 10 bells for fallen #firefighte...
# 166     166  workshop in #genderissues in #stem education -...
# 173     173  la #koreatown this place is legit. i was only ...
# 186     186  #teammscarter, my mom &amp; i are celebrating ...
# 200     200          clothes soaked #workout #mondaymotivation
# 212     212       . the . crew at the #xboxe3 media briefing
# 218     218  working on the talk i'm giving tomorrow at lun...
# 248     248  kicking off #mtpcon with a bang!  be sure to s...
# 253     253   is there a basketball game tonight? #imissjeter
# 273     273  exited for the premier of 47 meters down. exit...
# 317     317  not calling over the back fouls on #cavs now??...
# 353     353                                  lit #mia say....
# 369     369  had a wonderful time walking around the #nohoa...
# 398     398  i wish there was a new #stillstarcrossed tonig...
# 409     409  the incredible kicking things off at #larising...
# 418     418                           love you guys 45k 🤘 #rt
# 426     426  dropping weight #bianchi #bianchicycles #cardi...
# 489     489                                 cool bar! #e32017
# 497     497           crowd reaction is  #shadowofthecolossus
# 510     510  going to be #backhomeagaininindiana around 5:0...
# 527     527  i travelled 3,000 miles to watch lebron lose a...
# 535     535  my dinner date tonight is the #xboxonex soc ch...
# 541     541  ready for #concert #concertaddict #ilovemusic ...
# 614     614  100's of #shorttermrental supporters wait for ...
# 629     629                              grubbing with #smwla
# 640     640                               let's go #yankees!!
# 659     659  #serving #sunday #shade  at monthly #croptop p...
# 699     699  "losses are part of what we do." ~ on how soci...
# ...     ...                                                ...
# 7555   7555                      the #xboxe3 booth is packed!
# 7567   7567  eight full moons here in magical #mexico an ex...
# 7582   7582  as i was staring out the window at work, i see...
# 7612   7612  check out our #listing in #lascruces #nm #real...
# 7621   7621               #sessions##your eyes give you away#
# 7625   7625  we had a great group of music industry profess...
# 7647   7647                      nintendo booth is crazy! #e3
# 7688   7688  ❤️ this #es7 `::` shortcut for `.bind(this)` o...
# 7710   7710                          #e32017 - are you ready?
# 7752   7752  . we made it! so excited to check out all the ...
# 7770   7770  just heard a shoutout to #ethereum from #mtpco...
# 7772   7772                           just chillin at #e32017
# 7811   7811  check our instagram story to see all the behin...
# 7827   7827  more fun at annual meeting starring #2u ceo, #...
# 7831   7831  great advice &amp; tips "how to" be appointed ...
# 7836   7836  meanwhile in your neck of the woods...most aff...
# 7889   7889  see a virtual tour of my listing on 8 gold pop...
# 7924   7924   rooted in traditional values, hard work and e...
# 7941   7941  we found some of the founders at the #mvci boo...
# 7948   7948  a majestic welcome to #5style #aqualover #live...
# 7987   7987  #e32017 follow me set me free trust me and we ...
# 8016   8016  #photobooth #fun at the x #e32017 pre-party la...
# 8039   8039                            your move, tf2 #e32017
# 8042   8042  best #socialmedia event in june? vidcon? not t...
# 8105   8105  today was such an experience, so happy i commi...
# 8118   8118  join us on the #e3 floor at the #pcgamingshow ...
# 8123   8123  "you're in love with a psycho" -  #basevarsovi...
# 8133   8133  congratulations to our maestro en casa #gradua...
# 8139   8139  boobie ninjas with water guns coming this summ...
# 8144   8144  boobie ninjas with water guns coming this summ...
#
#                           created_at        date           date_time  \
# 30    Tue Jun 13 02:45:13 +0000 2017  2017-06-13 2017-06-13 02:45:13
# 57    Tue Jun 13 02:46:20 +0000 2017  2017-06-13 2017-06-13 02:46:20
# 129   Tue Jun 13 02:49:15 +0000 2017  2017-06-13 2017-06-13 02:49:15
# 166   Tue Jun 13 02:51:05 +0000 2017  2017-06-13 2017-06-13 02:51:05
# 173   Tue Jun 13 02:51:30 +0000 2017  2017-06-13 2017-06-13 02:51:30
# 186   Tue Jun 13 02:52:26 +0000 2017  2017-06-13 2017-06-13 02:52:26
# 200   Tue Jun 13 02:53:15 +0000 2017  2017-06-13 2017-06-13 02:53:15
# 212   Tue Jun 13 02:53:41 +0000 2017  2017-06-13 2017-06-13 02:53:41
# 218   Tue Jun 13 02:54:00 +0000 2017  2017-06-13 2017-06-13 02:54:00
# 248   Tue Jun 13 02:54:59 +0000 2017  2017-06-13 2017-06-13 02:54:59
# 253   Tue Jun 13 02:55:15 +0000 2017  2017-06-13 2017-06-13 02:55:15
# 273   Tue Jun 13 02:56:18 +0000 2017  2017-06-13 2017-06-13 02:56:18
# 317   Tue Jun 13 02:58:13 +0000 2017  2017-06-13 2017-06-13 02:58:13
# 353   Tue Jun 13 02:59:17 +0000 2017  2017-06-13 2017-06-13 02:59:17
# 369   Tue Jun 13 02:59:34 +0000 2017  2017-06-13 2017-06-13 02:59:34
# 398   Tue Jun 13 03:00:55 +0000 2017  2017-06-13 2017-06-13 03:00:55
# 409   Tue Jun 13 03:01:21 +0000 2017  2017-06-13 2017-06-13 03:01:21
# 418   Tue Jun 13 03:01:33 +0000 2017  2017-06-13 2017-06-13 03:01:33
# 426   Tue Jun 13 03:01:42 +0000 2017  2017-06-13 2017-06-13 03:01:42
# 489   Tue Jun 13 03:04:04 +0000 2017  2017-06-13 2017-06-13 03:04:04
# 497   Tue Jun 13 03:04:22 +0000 2017  2017-06-13 2017-06-13 03:04:22
# 510   Tue Jun 13 03:05:11 +0000 2017  2017-06-13 2017-06-13 03:05:11
# 527   Tue Jun 13 03:05:44 +0000 2017  2017-06-13 2017-06-13 03:05:44
# 535   Tue Jun 13 03:06:07 +0000 2017  2017-06-13 2017-06-13 03:06:07
# 541   Tue Jun 13 03:06:46 +0000 2017  2017-06-13 2017-06-13 03:06:46
# 614   Tue Jun 13 19:46:35 +0000 2017  2017-06-13 2017-06-13 19:46:35
# 629   Tue Jun 13 19:46:58 +0000 2017  2017-06-13 2017-06-13 19:46:58
# 640   Tue Jun 13 03:10:35 +0000 2017  2017-06-13 2017-06-13 03:10:35
# 659   Tue Jun 13 03:11:14 +0000 2017  2017-06-13 2017-06-13 03:11:14
# 699   Tue Jun 13 03:12:35 +0000 2017  2017-06-13 2017-06-13 03:12:35
# ...                              ...         ...                 ...
# 7555  Tue Jun 13 20:40:17 +0000 2017  2017-06-13 2017-06-13 20:40:17
# 7567  Tue Jun 13 20:40:28 +0000 2017  2017-06-13 2017-06-13 20:40:28
# 7582  Tue Jun 13 20:40:48 +0000 2017  2017-06-13 2017-06-13 20:40:48
# 7612  Tue Jun 13 20:41:24 +0000 2017  2017-06-13 2017-06-13 20:41:24
# 7621  Tue Jun 13 20:41:37 +0000 2017  2017-06-13 2017-06-13 20:41:37
# 7625  Tue Jun 13 20:41:43 +0000 2017  2017-06-13 2017-06-13 20:41:43
# 7647  Tue Jun 13 20:41:59 +0000 2017  2017-06-13 2017-06-13 20:41:59
# 7688  Tue Jun 13 19:47:12 +0000 2017  2017-06-13 2017-06-13 19:47:12
# 7710  Tue Jun 13 19:47:50 +0000 2017  2017-06-13 2017-06-13 19:47:50
# 7752  Tue Jun 13 19:49:25 +0000 2017  2017-06-13 2017-06-13 19:49:25
# 7770  Tue Jun 13 19:49:56 +0000 2017  2017-06-13 2017-06-13 19:49:56
# 7772  Tue Jun 13 19:49:57 +0000 2017  2017-06-13 2017-06-13 19:49:57
# 7811  Tue Jun 13 19:51:19 +0000 2017  2017-06-13 2017-06-13 19:51:19
# 7827  Tue Jun 13 19:51:50 +0000 2017  2017-06-13 2017-06-13 19:51:50
# 7831  Tue Jun 13 19:51:54 +0000 2017  2017-06-13 2017-06-13 19:51:54
# 7836  Tue Jun 13 19:52:05 +0000 2017  2017-06-13 2017-06-13 19:52:05
# 7889  Tue Jun 13 19:53:23 +0000 2017  2017-06-13 2017-06-13 19:53:23
# 7924  Tue Jun 13 19:54:40 +0000 2017  2017-06-13 2017-06-13 19:54:40
# 7941  Tue Jun 13 19:55:03 +0000 2017  2017-06-13 2017-06-13 19:55:03
# 7948  Tue Jun 13 19:55:14 +0000 2017  2017-06-13 2017-06-13 19:55:14
# 7987  Tue Jun 13 19:55:57 +0000 2017  2017-06-13 2017-06-13 19:55:57
# 8016  Tue Jun 13 19:56:38 +0000 2017  2017-06-13 2017-06-13 19:56:38
# 8039  Tue Jun 13 19:57:50 +0000 2017  2017-06-13 2017-06-13 19:57:50
# 8042  Tue Jun 13 19:57:57 +0000 2017  2017-06-13 2017-06-13 19:57:57
# 8105  Tue Jun 13 20:00:21 +0000 2017  2017-06-13 2017-06-13 20:00:21
# 8118  Tue Jun 13 20:00:49 +0000 2017  2017-06-13 2017-06-13 20:00:49
# 8123  Tue Jun 13 20:00:57 +0000 2017  2017-06-13 2017-06-13 20:00:57
# 8133  Tue Jun 13 20:01:08 +0000 2017  2017-06-13 2017-06-13 20:01:08
# 8139  Tue Jun 13 20:01:24 +0000 2017  2017-06-13 2017-06-13 20:01:24
# 8144  Tue Jun 13 20:01:32 +0000 2017  2017-06-13 2017-06-13 20:01:32
#
#                                                hashtags  \
# 30     friends weho wine la weekend guitar folk pop ...
# 57                        playstatione3 playstationasia
# 129                               firefighter rip lodd
# 166                                   genderissues stem
# 173                    koreatown holeinthewall foodporn
# 186                                       teammscarter
# 200                            workout mondaymotivation
# 212                                              xboxe3
# 218                                     react_on_rails
# 248                                              mtpcon
# 253                                          imissjeter
# 273                             47metersdown mandymoore
# 317                                      cavs nbafinals
# 353                                                 mia
# 369        nohoartsdistrict mydayinla northhollywood la
# 398                                    stillstarcrossed
# 409                                      larising smwla
# 418                                                  rt
# 426    bianchi bianchicycles cardio roadbike cycling...
# 489                                              e32017
# 497                                 shadowofthecolossus
# 510                 backhomeagaininindiana flyovernight
# 527                                            warriors
# 535                                            xboxonex
# 541    concert concertaddict ilovemusic musicislife ...
# 614      shorttermrental lacitycouncil planning landuse
# 629                                               smwla
# 640                                            yankees
# 659                serving sunday shade croptop xoxotye
# 699                                      larising smwla
# ...                                                 ...
# 7555                                             xboxe3
# 7567                mexico travel ttot tuesdaythoughts
# 7582                                    ilovefoodtrucks
# 7612            listing lascruces nm realestate realtor
# 7621                                sessions your away
# 7625                                      jamesonsummer
# 7647                                                 e3
# 7688                                                es7
# 7710                                             e32017
# 7752                                   gaming e3 e32017
# 7770                                    ethereum mtpcon
# 7772                                             e32017
# 7811                              e32017 legodimensions
# 7827          2u technology tech fun edtech edtechchat
# 7831                             sheshares womenleaders
# 7836                                          letterman
# 7889                              santafe nm realestate
# 7924                                      awardwinning
# 7941                            mvci e32017 marvellives
# 7948   5style aqualover liveaquaplaya mexico luxuryr...
# 7987                                             e32017
# 8016   photobooth fun e32017 e3expo soitbegins gamer...
# 8039                                             e32017
# 8042                                 socialmedia denver
# 8105                                 officiallyaleopard
# 8118                                    e3 pcgamingshow
# 8123                                       basevarsovia
# 8133                       graduates lifelong learners
# 8139                             senrankagura e3 e32017
# 8144                             senrankagura e3 e32017
#
#                                           location      time  \
# 30                                          bar 20  02:45:13
# 57                   shrine auditorium & expo hall  02:46:20
# 129                           lafd fire station 92  02:49:15
# 166                                         méxico  02:51:05
# 173                          han bat sul lung tang  02:51:30
# 186                                     crustacean  02:52:26
# 200                                new mexico, usa  02:53:15
# 212                             galen center (gec)  02:53:41
# 218                     castellemmare, los angeles  02:54:00
# 248                                      designmap  02:54:59
# 253                                      the big a  02:55:15
# 273                       village theatre westwood  02:56:18
# 317                    union square, san francisco  02:58:13
# 353                                      big wangs  02:59:17
# 369                             noho arts district  02:59:34
# 398                                         mexico  03:00:55
# 409                                     smogshoppe  03:01:21
# 418                                    stoner park  03:01:33
# 426                         coyote creek bike path  03:01:42
# 489                                     the one up  03:04:04
# 497                  shrine auditorium & expo hall  03:04:22
# 510      san francisco international airport (sfo)  03:05:11
# 527                              momo's restaurant  03:05:44
# 535                                palm restaurant  03:06:07
# 541                                  rickshaw stop  03:06:46
# 614                l.a. city hall council chambers  19:46:35
# 629                   the eli & edythe broad stage  19:46:58
# 640                       angel stadium of anaheim  03:10:35
# 659                                       sf oasis  03:11:14
# 699                                     smogshoppe  03:12:35
# ...                                            ...       ...
# 7555                     central city, los angeles  20:40:17
# 7567                                        mexico  20:40:28
# 7582                                t-mobile store  20:40:48
# 7612                               new mexico, usa  20:41:24
# 7621                               new mexico, usa  20:41:37
# 7625                               the lost church  20:41:43
# 7647                 los angeles convention center  20:41:59
# 7688                south of market, san francisco  19:47:12
# 7710                 los angeles convention center  19:47:50
# 7752                 los angeles convention center  19:49:25
# 7770                louise m. davies symphony hall  19:49:56
# 7772                 los angeles convention center  19:49:57
# 7811                 los angeles convention center  19:51:19
# 7827  long beach convention & entertainment center  19:51:50
# 7831                                 citizen hotel  19:51:54
# 7836                                      the loin  19:52:05
# 7889                               new mexico, usa  19:53:23
# 7924                               new mexico, usa  19:54:40
# 7941                 los angeles convention center  19:55:03
# 7948                                        mexico  19:55:14
# 7987                 los angeles convention center  19:55:57
# 8016                                   exchange la  19:56:38
# 8039                 los angeles convention center  19:57:50
# 8042                                         arkon  19:57:57
# 8105                        university of la verne  20:00:21
# 8118                             lacc south hall k  20:00:49
# 8123                                        méxico  20:00:57
# 8133                          st. aloysius gonzaga  20:01:08
# 8139                 los angeles convention center  20:01:24
# 8144                 los angeles convention center  20:01:32
#
#                                           tweet_content    created_datetime  \
# 30    great nite @bar20onsunset!! shoulda been there... 2017-06-13 02:45:13
# 57    well, that was quite some show! #playstatione3... 2017-06-13 02:46:20
# 129   the ringing of 10 bells for @lafd fallen #fire... 2017-06-13 02:49:15
# 166   workshop in #genderissues in #stem education -... 2017-06-13 02:51:05
# 173   la #koreatown this place is legit. i was only ... 2017-06-13 02:51:30
# 186   #teammscarter, my mom &amp; i are celebrating ... 2017-06-13 02:52:26
# 200           clothes soaked #workout #mondaymotivation 2017-06-13 02:53:15
# 212   .@marissaroberto the .@xboxcanada crew at the ... 2017-06-13 02:53:41
# 218   working on the talk i'm giving tomorrow at lun... 2017-06-13 02:54:00
# 248   kicking off #mtpcon with a bang! 💥 be sure to ... 2017-06-13 02:54:59
# 253   is there a basketball game tonight? #imissjete... 2017-06-13 02:55:15
# 273   exited for the premier of 47 meters down.  exi... 2017-06-13 02:56:18
# 317   not calling over the back fouls on #cavs now??... 2017-06-13 02:58:13
# 353            lit #mia say.... https://t.co/incm7qjr8a 2017-06-13 02:59:17
# 369   had a wonderful time walking around the #nohoa... 2017-06-13 02:59:34
# 398   i wish there was a new #stillstarcrossed tonig... 2017-06-13 03:00:55
# 409   the incredible @melanie_cara kicking things of... 2017-06-13 03:01:21
# 418    love you guys  45k 🤘 #rt https://t.co/hcabo0lb0p 2017-06-13 03:01:33
# 426   dropping weight 🚴🔥#bianchi #bianchicycles #car... 2017-06-13 03:01:42
# 489           cool bar! #e32017 https://t.co/z9xkoyaufa 2017-06-13 03:04:04
# 497   crowd reaction is 💰   #shadowofthecolossus htt... 2017-06-13 03:04:22
# 510   going to be #backhomeagaininindiana around 5:0... 2017-06-13 03:05:11
# 527   i travelled 3,000 miles to watch lebron lose a... 2017-06-13 03:05:44
# 535   my dinner date tonight is the #xboxonex soc ch... 2017-06-13 03:06:07
# 541   ready for @circawaves!!! #concert #concertaddi... 2017-06-13 03:06:46
# 614   100's of #shorttermrental supporters wait for ... 2017-06-13 19:46:35
# 629   grubbing with @bordergrill @smwla 🍴#smwla http... 2017-06-13 19:46:58
# 640         let's go #yankees!! https://t.co/or92uvvq4h 2017-06-13 03:10:35
# 659   #serving #sunday #shade 👄🖤🕶🌴 at @galendrever's... 2017-06-13 03:11:14
# 699   "losses are part of what we do." ~ on how soci... 2017-06-13 03:12:35
# ...                                                 ...                 ...
# 7555  the #xboxe3 booth is packed! https://t.co/blgy... 2017-06-13 20:40:17
# 7567  eight full moons here in magical #mexico an ex... 2017-06-13 20:40:28
# 7582  as i was staring out the window at work, i see... 2017-06-13 20:40:48
# 7612  check out our #listing in #lascruces #nm  #rea... 2017-06-13 20:41:24
# 7621  #sessions##your eyes give you away# https://t.... 2017-06-13 20:41:37
# 7625  we had a great group of music industry profess... 2017-06-13 20:41:43
# 7647  nintendo booth is crazy! #e3 https://t.co/gtbh... 2017-06-13 20:41:59
# 7688  ❤️ this #es7 `::` shortcut for `.bind(this)`  ... 2017-06-13 19:47:12
# 7710   #e32017 - are you ready? https://t.co/2bcaqomnya 2017-06-13 19:47:50
# 7752  .@xboxcanada we made it! so excited to check o... 2017-06-13 19:49:25
# 7770  just heard a shoutout to #ethereum from @hello... 2017-06-13 19:49:56
# 7772    just chillin at #e32017 https://t.co/ds3mkg732y 2017-06-13 19:49:57
# 7811  check our instagram story to see all the behin... 2017-06-13 19:51:19
# 7827  more fun at @2uinc annual meeting starring #2u... 2017-06-13 19:51:50
# 7831  great advice &amp; tips "how to" be appointed ... 2017-06-13 19:51:54
# 7836  meanwhile in your neck of the woods...most aff... 2017-06-13 19:52:05
# 7889  see a virtual tour of my listing on 8 gold pop... 2017-06-13 19:53:23
# 7924  https://t.co/bvvnsn2beb rooted in traditional ... 2017-06-13 19:54:40
# 7941  we found some of the @curlehcircuit founders a... 2017-06-13 19:55:03
# 7948  a majestic welcome to @liveaquaplaya. #5style ... 2017-06-13 19:55:14
# 7987  #e32017  follow me  set me free  trust me and ... 2017-06-13 19:55:57
# 8016  #photobooth #fun at the  @monstercat x @faceit... 2017-06-13 19:56:38
# 8039     your move, tf2 #e32017 https://t.co/cootlxuuii 2017-06-13 19:57:50
# 8042  best #socialmedia event in june? vidcon? not t... 2017-06-13 19:57:57
# 8105  today was such an experience, so happy i commi... 2017-06-13 20:00:21
# 8118  join us on the #e3 floor at the #pcgamingshow ... 2017-06-13 20:00:49
# 8123  "you're in love with a psycho" - @kasabianhq: ... 2017-06-13 20:00:57
# 8133  congratulations to our maestro en casa #gradua... 2017-06-13 20:01:08
# 8139  boobie ninjas with water guns coming this summ... 2017-06-13 20:01:24
# 8144  boobie ninjas with water guns coming this summ... 2017-06-13 20:01:32
#
#       year  month  day  hour
# 30    2017      6   13     2
# 57    2017      6   13     2
# 129   2017      6   13     2
# 166   2017      6   13     2
# 173   2017      6   13     2
# 186   2017      6   13     2
# 200   2017      6   13     2
# 212   2017      6   13     2
# 218   2017      6   13     2
# 248   2017      6   13     2
# 253   2017      6   13     2
# 273   2017      6   13     2
# 317   2017      6   13     2
# 353   2017      6   13     2
# 369   2017      6   13     2
# 398   2017      6   13     3
# 409   2017      6   13     3
# 418   2017      6   13     3
# 426   2017      6   13     3
# 489   2017      6   13     3
# 497   2017      6   13     3
# 510   2017      6   13     3
# 527   2017      6   13     3
# 535   2017      6   13     3
# 541   2017      6   13     3
# 614   2017      6   13    19
# 629   2017      6   13    19
# 640   2017      6   13     3
# 659   2017      6   13     3
# 699   2017      6   13     3
# ...    ...    ...  ...   ...
# 7555  2017      6   13    20
# 7567  2017      6   13    20
# 7582  2017      6   13    20
# 7612  2017      6   13    20
# 7621  2017      6   13    20
# 7625  2017      6   13    20
# 7647  2017      6   13    20
# 7688  2017      6   13    19
# 7710  2017      6   13    19
# 7752  2017      6   13    19
# 7770  2017      6   13    19
# 7772  2017      6   13    19
# 7811  2017      6   13    19
# 7827  2017      6   13    19
# 7831  2017      6   13    19
# 7836  2017      6   13    19
# 7889  2017      6   13    19
# 7924  2017      6   13    19
# 7941  2017      6   13    19
# 7948  2017      6   13    19
# 7987  2017      6   13    19
# 8016  2017      6   13    19
# 8039  2017      6   13    19
# 8042  2017      6   13    19
# 8105  2017      6   13    20
# 8118  2017      6   13    20
# 8123  2017      6   13    20
# 8133  2017      6   13    20
# 8139  2017      6   13    20
# 8144  2017      6   13    20
#
# [328 rows x 14 columns]

# %%
ca_df = df[df['location'].str.contains('.ca|california')]
tx_df = df[df['location'].str.contains('.tx|texas')]

# %%
def word_cloud(state = None): 
    state = state.lower()
    state_df = df[df['location'].str.contains('.{}'.format(state))]
    words = state_df['hashtags'][(state_df['hashtags'].isnull() == False) & (state_df['hashtags'] != 'None')]
    stopwords = set(STOPWORDS)
    #stopwords.add("amp")
    wc = WordCloud(width=1600, height=800, background_color='white', \
                   relative_scaling=1, stopwords=stopwords, colormap='copper').generate(' '.join(i for i in words))
    plt.figure(figsize=(20,10))
    plt.imshow(wc)
    plt.axis("off")
    plt.show()
    return

# %%
word_cloud('TX')

# %%
word_cloud('CA')

# %%
hastages_series = df['hashtags']
len(hastages_series)
# Out:
# 6705

# %%
count_vectorizer = CountVectorizer(min_df = 1, stop_words='english')
hashtags_countvec = count_vectorizer.fit_transform(hastages_series)
#hashtags_countvec = pickle.dumps(hashtags_countvec_fit)
#r.set('hashtags_countvec_fit_temp', hashtags_countvec)
#hashtags_countvec = pickle.loads(r.get('hashtags_countvec_fit_temp'))

# %%
time_delta = max(df['created_datetime']) - min(df['created_datetime'])
time_window = time_delta.components.days*24 + time_delta.components.hours
time_lag = timedelta(hours = .25)
time_gap = timedelta(hours = 0.1)
windows = int(round(time_delta/time_gap,0))
print('start time: ', min(df['created_datetime']),'\n',\
      'end time:  ', max(df['created_datetime']),'\n',\
      'total hours: ',time_window,'\n',\
      'time lag: ', time_lag,'\n',\
      'time gap: ', time_gap,'\n',\
      'time windows: ', windows)
# Out:
# start time:  2017-06-13 02:43:25
#  end time:   2017-06-13 20:43:11
#  total hours:  17
#  time lag:  0:15:00
#  time gap:  0:06:00
#  time windows:  180

# %%
def group_consecutives(vals, step=1):
    """Return list of consecutive lists of numbers from vals (number list)."""
    run = []
    result = [run]
    expect = None
    for v in vals:
        if (v == expect) or (expect is None):
            run.append(v)
        else:
            run = [v]
            result.append(run)
        expect = v + step
    
    return result

# %%
def new_trend_period(trend_group):        
    new_result = []
    count = 0
    for i in range(len(trend_group)-1):
        if (count > len(trend_group)-2):
            pass
        else:
            gap = ((trend_group[count+1][0]) - (trend_group[count][len(trend_group[count])-1]))
            if gap <.8*min((trend_group[count+1][0]), (trend_group[count][len(trend_group[count])-1])):
                new_period = trend_group[count]+trend_group[count+1]
                new_result.append(new_period)
                count +=2
            else:
                new_result.append(trend_group[count])
                count +=1
    return new_result

# %%
time_delta = max(df['created_datetime']) - min(df['created_datetime'])
time_window = time_delta.components.days*24 + time_delta.components.hours
time_lag = timedelta(hours = .3)
time_gap = timedelta(hours = .1)
windows = int(round(time_delta/time_gap,0))
time_format = '%Y-%h-%d %a %I %p'
from_zone = tz.tzutc()
#to_zone = tz.tzlocal()
to_zone = 'US/Pacific'
def hashtag_trend(hashtag):
    hashtag = hashtag.lower()
    arr = []
    arr_all = []
    start_time = min(df['created_datetime'])
    for window in range(windows):
        start_time = start_time
        end_time = start_time + time_lag
        subset = df['hashtags'][((df['created_datetime'] < end_time) & (df['created_datetime'] > start_time))]
        h = subset.str.contains(hashtag).mean()
        arr.append(h)
        #arr_all.append(subset.mean())
        start_time += time_gap
    w = np.array(range(windows))
    timeline = []
    for i in w:
        timeline.append(min(df['created_datetime']) + time_gap * i) 
    arr = np.array(arr)  
    #arr_all = np.array(arr_all) 
    grad = np.gradient(arr)
    #grad2 = np.gradient(grad)
    #tr = np.argwhere(grad>.01).reshape(1,-1)[0]
    time_df = pd.DataFrame({'arr':arr,'grad':grad},index=timeline)
    rolmean_arr = pd.rolling_mean(arr, window=12)
    rolstd_arr = pd.rolling_std(arr, window=12)
    rolmean_grad = np.gradient(rolmean_arr)
    spike = []
    trend = np.argwhere(rolmean_grad>0.001).reshape(1,-1)[0]
    trend_group = group_consecutives(trend)
        
    trend_group1 = new_trend_period(trend_group)
    #if trend_group1 != trend_group:
    #    trend_group1 = new_trend_period(trend_group1)
        
    trend_group2 = [i for i in trend_group1 if (len(i) > 7)]
    spike.append([[i[0],i[len(i)-1]] for i in trend_group2])
    spike = np.array(spike)
    spk1 = [i[0] for i in spike[0]]
    spk2 = [i[1] for i in spike[0]]
        
    plt.figure(figsize=(14,7))
    plt.plot(arr, label='Hashtag Frequency',c = 'navy')
    plt.plot(rolmean_arr, label='Rolling Means',c = 'lightblue')
    plt.plot(rolstd_arr, label='Rolling STDs',c = 'gray')
    plt.plot(rolmean_grad, label='Gradient over Rolling Means',c = 'red')
    #plt.plot(grad2, label='grad2 Slope')
    for j,k in zip(spk1,spk2):
        spike1 = (min(df['created_datetime']) + time_gap * j) 
        spike1 = spike1.replace(tzinfo=from_zone)
        spike1_et = spike1.astimezone(to_zone)
        spike1_et = spike1_et.strftime(time_format)
       
        spike2 = (min(df['created_datetime']) + time_gap * k) 
        spike2 = spike2.replace(tzinfo=from_zone)
        spike2_et = spike2.astimezone(to_zone)
        spike2_et = spike2_et.strftime(time_format)           
        plt.axvline(j, color = 'salmon',linestyle='dashed', label = 'Trending: {}'.format(spike1_et))
        plt.axvspan(j, k, alpha=0.2, color='lightcoral')
    plt.title(hashtag, fontsize=20)    
    plt.legend(fontsize=12) 
    ### -----ARIMA MODELING
#     from statsmodels.tsa.arima_model import ARIMA
#     w = np.array(range(windows))
#     timeline = []
#     for i in w:
#         timeline.append(min(df['created_datetime']) + time_gap * i) 
#     arima_df = pd.DataFrame({'perf':arr},index=timeline)   

#     series = arima_df
#     model = ARIMA(series, order=(5,1,0))
#     model_fit = model.fit()
#     print(model_fit.summary())
#     # plot residual errors
#     residuals =pd. DataFrame(model_fit.resid)
#     residuals.plot()
#     plt.show()
#     residuals.plot(kind='kde')
#     plt.show()
#     print(residuals.describe())
    ###-----------------
    return  time_df

# %%
hashtag_freq_df = pd.DataFrame({'hashtag': count_vectorizer.get_feature_names(), 'occurrences':np.asarray(hashtags_countvec.sum(axis=0)).ravel().tolist()})
hashtag_freq_df['frequency'] = hashtag_freq_df['occurrences']/np.sum(hashtag_freq_df['occurrences'])
hashtag_freq_df.sort_values(by = 'occurrences',ascending = False, inplace = True)

# %%
hashtag_freq_df.head(10)
# Out:
#               hashtag  occurrences  frequency
# 3396        nbafinals          600   0.050514
# 4351  sessionshearing          523   0.044031
# 1419        dubnation          393   0.033086
# 1457           e32017          239   0.020121
# 3398    nbafinals2017          183   0.015407
# 5445         warriors          178   0.014986
# 2580     jeffsessions          175   0.014733
# 1454               e3          158   0.013302
# 4348         sessions           82   0.006904
# 4529            smwla           60   0.005051

# %%
a = [hashtag_trend(i) for i in (hashtag_freq_df['hashtag'].head(20))]
# Out:
# /opt/conda/lib/python3.5/site-packages/ipykernel_launcher.py:33: FutureWarning: pd.rolling_mean is deprecated for ndarrays and will be removed in a future version
# /opt/conda/lib/python3.5/site-packages/ipykernel_launcher.py:34: FutureWarning: pd.rolling_std is deprecated for ndarrays and will be removed in a future version
# /opt/conda/lib/python3.5/site-packages/ipykernel_launcher.py:37: RuntimeWarning: invalid value encountered in greater

# %%
time_df = hashtag_trend('pride2017')
# Out:
# /opt/conda/lib/python3.5/site-packages/ipykernel_launcher.py:33: FutureWarning: pd.rolling_mean is deprecated for ndarrays and will be removed in a future version
# /opt/conda/lib/python3.5/site-packages/ipykernel_launcher.py:34: FutureWarning: pd.rolling_std is deprecated for ndarrays and will be removed in a future version
# /opt/conda/lib/python3.5/site-packages/ipykernel_launcher.py:37: RuntimeWarning: invalid value encountered in greater

# %% [raw]
# import matplotlib.pyplot as plt
# import numpy as np
# import pandas as pd
# def svd_variance(svd_model, col_index):
#
#     dimensions = ['Dimension {}'.format(i) for i in range(1,len(svd_model.components_)+1)]
#     components = pd.DataFrame(np.round(svd_model.components_, 4), columns=col_index)
#     ratios = svd_model.explained_variance_ratio_.reshape(len(svd_model.components_), 1)
#     variance_ratios = pd.DataFrame(np.round(ratios, 4), columns = ['Explained Variance'])
#     variance_ratios.index = dimensions
#
#     fig, ax = plt.subplots(figsize = (24,10))
#
#     # Plot the feature weights as a function of the components
#     components.plot(ax = ax, kind = 'bar',legend='False');
#     ax.set_ylabel("Feature Weights")
#     ax.set_xticklabels(dimensions, rotation=0)
#     ax.legend_.remove()
#
#
#     # Display the explained variance ratios
#     for i, ev in enumerate(svd_model.explained_variance_ratio_):
#         ax.text(i-0.40, ax.get_ylim()[1] + 0.05, "Explained Variance\n          %.4f"%(ev))

# %% [raw]
# svd_variance(svd, tfd_word_index)

# %% [raw]
# cv_svd_pipe = Pipeline([
#     ('cv',CountVectorizer(min_df = 1, stop_words='english')),
#     ('svd',TruncatedSVD(n_components=25))
# ])
# cv = cv_svd_pipe.steps[0][1]
# svd = cv_svd_pipe.steps[1][1]
