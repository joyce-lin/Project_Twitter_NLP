# %%
import pandas as pd
import numpy as np
from sklearn.decomposition import TruncatedSVD
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
import random
from sklearn.metrics.pairwise import cosine_similarity
import math
import tqdm
import matplotlib.pyplot as plt
# %matplotlib inline
# !pip install wordcloud
from wordcloud import WordCloud, STOPWORDS
# Out:
# Requirement already satisfied (use --upgrade to upgrade): wordcloud in /opt/conda/lib/python3.5/site-packages
# Requirement already satisfied (use --upgrade to upgrade): matplotlib in /opt/conda/lib/python3.5/site-packages (from wordcloud)
# Requirement already satisfied (use --upgrade to upgrade): numpy>=1.6.1 in /opt/conda/lib/python3.5/site-packages (from wordcloud)
# Requirement already satisfied (use --upgrade to upgrade): pillow in /opt/conda/lib/python3.5/site-packages (from wordcloud)
# Requirement already satisfied (use --upgrade to upgrade): six>=1.10 in /opt/conda/lib/python3.5/site-packages (from matplotlib->wordcloud)
# Requirement already satisfied (use --upgrade to upgrade): python-dateutil in /opt/conda/lib/python3.5/site-packages (from matplotlib->wordcloud)
# Requirement already satisfied (use --upgrade to upgrade): pytz in /opt/conda/lib/python3.5/site-packages (from matplotlib->wordcloud)
# Requirement already satisfied (use --upgrade to upgrade): cycler>=0.10 in /opt/conda/lib/python3.5/site-packages/cycler-0.10.0-py3.5.egg (from matplotlib->wordcloud)
# Requirement already satisfied (use --upgrade to upgrade): pyparsing!=2.0.4,!=2.1.2,!=2.1.6,>=1.5.6 in /opt/conda/lib/python3.5/site-packages (from matplotlib->wordcloud)
# Requirement already satisfied (use --upgrade to upgrade): olefile in /opt/conda/lib/python3.5/site-packages (from pillow->wordcloud)
# You are using pip version 8.1.2, however version 9.0.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
import psycopg2 as pg2
import psycopg2.extras as pgex
this_host='34.211.59.66'
this_user='postgres'
this_password='postgres'
conn = pg2.connect(host = this_host, 
                        user = this_user,
                        password = this_password)

sql_select = '''select created_at, location, tweet_content, cleaned_tweet, hashtags from tweets;'''

cur = conn.cursor(cursor_factory=pgex.RealDictCursor)
cur.execute(sql_select)
rows = cur.fetchall()
conn.close()
df = pd.DataFrame(rows)
df.reset_index(inplace = True)

# %%
import pickle
# !pip install redis
import redis
redis_ip = '34.211.59.66'
r = redis.StrictRedis(redis_ip)
r.keys()
# Out:
# Requirement already satisfied (use --upgrade to upgrade): redis in /opt/conda/lib/python3.5/site-packages
# You are using pip version 8.1.2, however version 9.0.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.
# [b'tweets_tfd_svd_pipe',
#  b'hashtags_countvec_fit_transform',
#  b'tweet_tfidf_fit',
#  b'tweet_tfidf_fit_transform',
#  b'hashtags_countvec_fit_temp',
#  b'temp_hash_count_12hr',
#  b'tweet_SVD_fit',
#  b'hashtags_countvec_fit',
#  b'hashtags_tfidf_fit_transform',
#  b'hashtag_tfidf']

# %%
tfd_svd_pipe = pickle.loads(r.get('tweets_tfd_svd_pipe'))

# %%
TFIDF_fit =  tfd_svd_pipe.steps[0][1]
SVD_fit = tfd_svd_pipe.steps[1][1]

# %% [markdown]
# TFIDF_fit = pickle.loads(r.get('tweet_tfidf_fit'))
# SVD_fit = pickle.loads(r.get('tweet_SVD_fit'))

# %%
def event_tweet_count(event):
    event = event.lower()
    event_tweet = df[df['cleaned_tweet'].str.contains((event))]
    return len(event_tweet)

# %%
def tweets_event_ab_test(event):
    event = event.lower()
    event_tweet = df[df['cleaned_tweet'].str.contains((event))]
    event_tweet.reset_index(inplace = True)
    
    A_index = list(range(event_tweet.shape[0]))
    random.shuffle(A_index)
    
    n = int(round((event_tweet_count(event))*0.2,0))
    A1_index = []
    for i in range(n):
        A1_index.append(A_index.pop())
    
    A1 = event_tweet.iloc[A1_index,:]
    A1_vec = np.array([SVD_fit.transform(TFIDF_fit.transform([i])).ravel() for i in A1['cleaned_tweet']])

    A2 = event_tweet.iloc[A_index,:] 
    #A2.reset_index(inplace = True)
    A2_vec = np.array([SVD_fit.transform(TFIDF_fit.transform([i])).ravel() for i in A2['cleaned_tweet']])
    non_event_tweet = df[~df['cleaned_tweet'].str.contains(('event'))]
    non_event_tweet.reset_index(inplace = True)
    
    B_index = list(range(non_event_tweet.shape[0]))
    random.shuffle(B_index)
    n = n
    B1_index = []
    for i in range(n):
        B1_index.append(B_index.pop())
    m = A2.shape[0]
    B2_index = []
    for i in range(m):
        B2_index.append(B_index.pop())  
    
    B1 = non_event_tweet.iloc[B1_index,:]
    B1_vec = np.array([SVD_fit.transform(TFIDF_fit.transform([i])).ravel() for i in B1['cleaned_tweet']])
    
    B2 = non_event_tweet.iloc[B2_index,:]
    B2_vec = np.array([SVD_fit.transform(TFIDF_fit.transform([i])).ravel() for i in B2['cleaned_tweet']])
    
    A1_vec_mean = np.mean(A1_vec, axis=0)
    A2_vec_mean = np.mean(A2_vec, axis=0)
    B1_vec_mean = np.mean(B1_vec, axis=0)
    B2_vec_mean = np.mean(B2_vec, axis=0)
    
    a1a2 = cosine_similarity(A1_vec_mean.reshape(1,-1),A2_vec_mean.reshape(1,-1))[0][0]
    b1b2 = cosine_similarity(B2_vec_mean.reshape(1,-1),B1_vec_mean.reshape(1,-1))[0][0]
    a1b1 = cosine_similarity(A1_vec_mean.reshape(1,-1),B1_vec_mean.reshape(1,-1))[0][0]
    a2b2 = cosine_similarity(A2_vec_mean.reshape(1,-1),B2_vec_mean.reshape(1,-1))[0][0]
   
    a2_consim_list = []
    for i in range(min(n,m)):  
        a2_consim_list.append(cosine_similarity(A2_vec[i].reshape(1,-1),A1_vec_mean.reshape(1,-1))[0][0])
    a2_mean = np.mean(np.array(a2_consim_list))
    a2_std = np.std(np.array(a2_consim_list))
    
    b2_consim_list = []
    for i in range(min(n,m)):  
        b2_consim_list.append(cosine_similarity(B2_vec[i].reshape(1,-1),B1_vec_mean.reshape(1,-1))[0][0])
    b2_mean = np.mean(b2_consim_list)
    b2_std = np.std(b2_consim_list)
    
    a1b2_consim_list = []
    for i in range(min(n,m)):  
        a1b2_consim_list.append((cosine_similarity(B2_vec[i].reshape(1,-1),A1_vec_mean.reshape(1,-1))[0][0]))
    a1b2_mean = np.mean(a1b2_consim_list)
    a1b2_std = np.std(a1b2_consim_list)
    
    print('A1|A2: ',round(a1a2,3),'\n'
                'B1|B2: ',round(b1b2,3), '\n\n'
                'A1|B1: ',round(a1b1,3), '\n'
                'A2|B2: ', round(a2b2,3), '\n\n'
                'Cosine Similarity Mean of A2 to A1', round(a2_mean,3), '\n'
                'Cosine Similarity Mean of B2 to B1', round(b2_mean,3), '\n'
                'Cosine Similarity Mean of B2 to A1', round(a1b2_mean,3), '\n\n'
                'Cosine Similarity STD of A2 to A1', round(a2_std,3), '\n'
                'Cosine Similarity STD of B2 to B1', round(b2_std,3), '\n'
                'Cosine Similarity STD of B2 to A1', round(a1b2_std,3), '\n'                 
                )
    
    return a2_consim_list, b2_consim_list

# %%
def check_score_cluster(event,check_by_score = .7,high_score = .9):
    event = event.lower()
    event_tweet = df[df['cleaned_tweet'].str.contains((event))]
    event_tweet.reset_index(inplace = True, drop=True)
    A_index = list(range(event_tweet.shape[0]))
    random.shuffle(A_index)

    n = int(round((event_tweet_count(event))*0.5,0))
    A1_index = []
    for i in range(n):
        A1_index.append(A_index.pop())

    A1 = event_tweet.iloc[A1_index,:]
    A1.reset_index(inplace = True, drop=True)
    A1_vec = SVD_fit.transform(TFIDF_fit.transform(A1['cleaned_tweet']))

    A2 = event_tweet.iloc[A_index,:] 
    A2_vec = SVD_fit.transform(TFIDF_fit.transform(A2['cleaned_tweet']))
    A1_vec_mean = np.mean(A1_vec, axis=0)
    A2_vec_mean = np.mean(A2_vec, axis=0)

    consim_twt_list = []
    for i in range(len(A1)):  
        consim_twt_list.append((cosine_similarity(A1_vec[i].reshape(1,-1),A2_vec_mean.reshape(1,-1))[0][0], A1['cleaned_tweet'][i]))
    #pd.options.display.max_colwidth = 200
    result = pd.DataFrame(consim_twt_list, columns = ['score','tweet'])
    cluster1 = result[result['score']>high_score].sort_values('score', ascending = False)
    cluster2 = result[((result['score']<(check_by_score+.05)) & (result['score']>(check_by_score-.05)))]\
                .sort_values('score', ascending = False)
    return pd.concat([cluster1.reset_index().head(30), cluster2.reset_index().head(30)], axis=1)

# %%
def Top_scored_tweets_in_B(event, n = 10000):
    event = event.lower()
    A = df[df['cleaned_tweet'].str.contains((event))]
    A.reset_index(inplace = True, drop=True)
    A_vec = SVD_fit.transform(TFIDF_fit.transform(A['cleaned_tweet']))
    A_vec_mean = np.average(A_vec, axis=0)
       
    B = df[~df['cleaned_tweet'].str.contains((event))]
    B_index = list(range(B.shape[0]))
    random.shuffle(B_index)
    n = n
    B1_index = []
    for i in range(n):
        B1_index.append(B_index.pop())
        
    B1 = B.iloc[B1_index,:]
    B1.reset_index(inplace = True, drop=True)
    B1_vec = SVD_fit.transform(TFIDF_fit.transform(B1['cleaned_tweet']))
    
    consim_twt_list = []
    for i in range(n):  
        consim_twt_list.append((cosine_similarity(B1_vec[i].reshape(1,-1),A_vec_mean.reshape(1,-1))[0][0], B1['cleaned_tweet'][i]))
    pd.options.display.max_colwidth = 200
    result = pd.DataFrame(consim_twt_list, columns = ['score','tweet'])
    cluster = result[result['score']>.7].sort_values('score', ascending = False)
    pd.set_option('display.max_colwidth', -1)
    return cluster.head(20)

# %%
words = df['hashtags'][(df['hashtags'].isnull() == False) & (df['hashtags'] != 'None')]
stopwords = set(STOPWORDS)
stopwords.add("job")
stopwords.add("careerarc")
stopwords.add("hiring")
wc = WordCloud(width=1600, height=800, background_color='white', \
               relative_scaling=1, stopwords=stopwords, colormap='copper').generate(' '.join(i for i in words))


plt.figure(figsize=(20,10))
plt.imshow(wc)
plt.axis("off")
plt.show()

# %%
print('Event Tweets (paris|climate): ', event_tweet_count('paris|climate'))
A, B = tweets_event_ab_test('paris|climate')
plt.scatter(range(len(A)), A, c = 'g')
plt.scatter(range(len(B)), B, c = 'r')
plt.ylim(-.1,1)
# Out:
# Event Tweets (paris|climate):  2627
# A1|A2:  0.997
# B1|B2:  0.984
#
# A1|B1:  0.874
# A2|B2:  0.891
#
# Cosine Similarity Mean of A2 to A1 0.448
# Cosine Similarity Mean of B2 to B1 0.315
# Cosine Similarity Mean of B2 to A1 0.297
#
# Cosine Similarity STD of A2 to A1 0.146
# Cosine Similarity STD of B2 to B1 0.12
# Cosine Similarity STD of B2 to A1 0.157
# (-0.1, 1)

# %%
check_score_cluster('paris|climate',.3, .7)
# Out:
#      index     score                                              tweet  \
# 0    410.0  0.771861  if climate change is real, go live in a grass ...
# 1    890.0  0.767023   i hate to break it to him but his job is gone...
# 2    189.0  0.766779  even the mayor of pittsburg is in accordance t...
# 3    120.0  0.760823  without the us in the paris climate change acc...
# 4   1280.0  0.760465   again the anger comes out in hurling insults....
# 5    201.0  0.752410  confirming we live in a backward reality: form...
# 6   1301.0  0.746706  makes no sense to pull out of the paris agreem...
# 7   1159.0  0.745050  "we, the people of the united states, sign on ...
# 8      4.0  0.738401  i find it shocking that the future of the eart...
# 9   1080.0  0.738322  we stand in solidarity w/people around the wor...
# 10   139.0  0.738253   joe walsh is a crank and you know that. he br...
# 11   632.0  0.738092  cnn: sources: acting us ambassador to china qu...
# 12   208.0  0.736339  the fact that the main cause of climate change...
# 13    34.0  0.731067  crazy to think these guys running the office w...
# 14   296.0  0.727400  when the president of the united states is a c...
# 15   879.0  0.723333  "does trump take a dump?" "the toilet paper ro...
# 16   333.0  0.719694   cant wait for the two of them (alone in the w...
# 17    57.0  0.714089  . is organizing a group of politicians, academ...
# 18   694.0  0.711991  as if trump knows more than the consensus of t...
# 19   650.0  0.708719  i pledge allegiance to the united states clima...
# 20   622.0  0.707841  i understand the nixon comparisons, as america...
# 21  1175.0  0.707450   don't you think trump wants to destroy the en...
# 22   856.0  0.706959   trump in one breath claims that the paris acc...
# 23   912.0  0.704481  guess what trump, once the us has sunk into th...
# 24     NaN       NaN                                                NaN
# 25     NaN       NaN                                                NaN
# 26     NaN       NaN                                                NaN
# 27     NaN       NaN                                                NaN
# 28     NaN       NaN                                                NaN
# 29     NaN       NaN                                                NaN
#
#     index     score                                              tweet
# 0    1041  0.349751   #climatechangeisafact #sciencesaysso it's not...
# 1    1267  0.349353  republican governor joins coalition to uphold ...
# 2     762  0.349209  u r mad a billionaire is doing good w/his mone...
# 3     327  0.348409  bruh i took a shit in paris hiltons bathroom y...
# 4     501  0.347950   climate-denies w/generalizations.you cite com...
# 5    1010  0.347920  climate change is fake, i suddenly don't belie...
# 6     905  0.346459  "our global #climate action movement will not ...
# 7    1230  0.345880  both #ford &amp; #gm say #unitedstates #parisa...
# 8    1046  0.345634  so this anxious wait for trump on paris climat...
# 9      94  0.345556   #climatechangeisreal al gore said after getti...
# 10    861  0.345096  from our department of inevitable nazi compari...
# 11   1055  0.345086   oh good i was about to go in ppl who don't be...
# 12    347  0.344974   about that "green climate fund", trump was mi...
# 13    824  0.344278  what's next for the paris accord. my inhabitat...
# 14    920  0.344278  what's next for the paris accord. my inhabitat...
# 15   1181  0.343674  ~70k us coal industry jobs vs 8m population po...
# 16     25  0.343515  i'm curious to know what a climate change deni...
# 17    132  0.343316  democrat donors are screaming bloody murder th...
# 18   1143  0.343316  democrat donors are screaming bloody murder th...
# 19     65  0.342977  it was signed in paris!!! it's not -- it doesn...
# 20   1180  0.341827  lmao trump and 22 other republican congressman...
# 21    644  0.341672  #parisagreement pfft. #tr0lcat pulls us out [s...
# 22    429  0.341495   who cares if you respect or don't respect tru...
# 23    646  0.341013  after donald abdicated our role as a global le...
# 24    619  0.340777  on #climatechange and #parisagreement: if you ...
# 25   1132  0.340191  if you care at all about climate anything in a...
# 26    674  0.339644  does believe that climate change is a hoax? th...
# 27     42  0.339281                 more face palming #parisagreement
# 28    157  0.339251   if he can destroy climate deal.....he can des...
# 29   1294  0.339154                 not qualified to speak for climate

# %%
print('Event Tweets (nbafinals): ', event_tweet_count('nbafinals'))
A, B = tweets_event_ab_test('nbafinals')
plt.scatter(range(len(A)), A, c = 'g')
plt.scatter(range(len(B)), B, c = 'r')
plt.ylim(-.1,1.2)
# Out:
# Event Tweets (nbafinals):  1183
# A1|A2:  0.987
# B1|B2:  0.976
#
# A1|B1:  0.847
# A2|B2:  0.891
#
# Cosine Similarity Mean of A2 to A1 0.365
# Cosine Similarity Mean of B2 to B1 0.308
# Cosine Similarity Mean of B2 to A1 0.284
#
# Cosine Similarity STD of A2 to A1 0.155
# Cosine Similarity STD of B2 to B1 0.127
# Cosine Similarity STD of B2 to A1 0.163
# (-0.1, 1.2)

# %%
#check high score tweets (>0.9) versus tweets with clustered scores 
check_score_cluster('nbafinals',.7)
# Out:
#     index  score tweet  index     score  \
# 0     NaN    NaN   NaN    196  0.722847
# 1     NaN    NaN   NaN    309  0.708723
# 2     NaN    NaN   NaN    139  0.689597
# 3     NaN    NaN   NaN    363  0.680959
# 4     NaN    NaN   NaN     75  0.680911
# 5     NaN    NaN   NaN    566  0.680542
# 6     NaN    NaN   NaN    519  0.672401
# 7     NaN    NaN   NaN    343  0.670215
# 8     NaN    NaN   NaN    172  0.660042
# 9     NaN    NaN   NaN     46  0.656839
# 10    NaN    NaN   NaN    493  0.650222
#
#                                                 tweet
# 0   remember ty lue saying the celtics were toughe...
# 1   when i went to #college the #nbafinals used to...
# 2   warriors celebrating kerr returning from a bac...
# 3   the #spellingbee on is a lot more competitive ...
# 4   didn't lue say the celtics were tougher to gua...
# 5   . damn. is the theme for the 2017 #nbafinals, ...
# 6   the have hit  points...in the 3rd quarter. ama...
# 7   i mean, after blowing a 3-1 lead last year to ...
# 8   the warriors defense has lead to the cavs turn...
# 9   the end got sloppy, but that was one of the mo...
# 10  great to see steve kerr back on the sidelines ...

# %%
check_score_cluster('nbafinal',.2)
# Out:
#     index  score tweet  index     score  \
# 0     NaN    NaN   NaN    203  0.247743
# 1     NaN    NaN   NaN    245  0.247087
# 2     NaN    NaN   NaN    107  0.246552
# 3     NaN    NaN   NaN    342  0.245920
# 4     NaN    NaN   NaN    137  0.242502
# 5     NaN    NaN   NaN    112  0.241383
# 6     NaN    NaN   NaN    332  0.240703
# 7     NaN    NaN   NaN    143  0.239951
# 8     NaN    NaN   NaN    202  0.239238
# 9     NaN    NaN   NaN    193  0.239138
# 10    NaN    NaN   NaN    582  0.238080
# 11    NaN    NaN   NaN    132  0.236553
# 12    NaN    NaN   NaN    151  0.235922
# 13    NaN    NaN   NaN    417  0.234819
# 14    NaN    NaN   NaN    328  0.231162
# 15    NaN    NaN   NaN    114  0.230500
# 16    NaN    NaN   NaN     80  0.230089
# 17    NaN    NaN   NaN    499  0.229450
# 18    NaN    NaN   NaN     54  0.228991
# 19    NaN    NaN   NaN    389  0.228966
# 20    NaN    NaN   NaN    410  0.228793
# 21    NaN    NaN   NaN    133  0.227928
# 22    NaN    NaN   NaN    198  0.227253
# 23    NaN    NaN   NaN     90  0.226940
# 24    NaN    NaN   NaN    350  0.225757
# 25    NaN    NaN   NaN    465  0.225431
# 26    NaN    NaN   NaN    543  0.225204
# 27    NaN    NaN   NaN    429  0.224835
# 28    NaN    NaN   NaN    278  0.224184
# 29    NaN    NaN   NaN    379  0.219471
#
#                                                 tweet
# 0                                 damn #nbafinals2017
# 1            kevin. durant. is. not. nice. #nbafinals
# 2   and take ur l's like a man #nbafinals #goldens...
# 3                thats how u play it ppl!! #nbafinals
# 4                         kyrie is a beast #nbafinals
# 5               shit! stop golden state! #nbafinals17
# 6   2-0 baby  #stephgonnasteph #dubnation #strengt...
# 7   cavs are getting frustrated already #nbafinals...
# 8                         this game tho...#nbafinals
# 9                            game one. #nbafinals2017
# 10  i'm not a cavs fan but can i be a fan?  #nbafi...
# 11                            cavs in -4  #nbafinals
# 12          not that much of a beauty.... #nbafinals
# 13  2 more ws and we are champs #dubnation #nbafinals
# 14  that 93 til infinity audio bed in that ad duri...
# 15  warriors....... come out and plaaaaaaaaay!!! #...
# 16  so glad for all these awesome turn overs #nbaf...
# 17         somebody got a spankin tonight. #nbafinals
# 18               dunks on dunks on dunks. #nbafinals
# 19                          this game! #nbafinals -p
# 20            these refs are some hos bruh #nbafinals
# 21  hey durant! colonel sanders just called. he wa...
# 22            #nbafinals golden state 59 cleveland 50
# 23           another 20 point blow out #nbafinals2017
# 24  nba has become so boring and predictable. #nba...
# 25  go warriors!!  #strengthinnumbers #dubnation #...
# 26                    durant is unreal #nbafinals2017
# 27                 let's go #warriors! #nbafinals2017
# 28  why is this turning into a blowout? ugh. #nbaf...
# 29                        omg this game. #nbafinals17

# %%
print('Event Tweets (wonderwoman): ', event_tweet_count('wonderwoman'))
A, B = tweets_event_ab_test('wonderwoman')
plt.scatter(range(len(A)), A, c = 'g')
plt.scatter(range(len(B)), B, c = 'r')
plt.ylim(-.1,1.2)
# Out:
# Event Tweets (wonderwoman):  1503
# A1|A2:  0.982
# B1|B2:  0.974
#
# A1|B1:  0.912
# A2|B2:  0.931
#
# Cosine Similarity Mean of A2 to A1 0.376
# Cosine Similarity Mean of B2 to B1 0.318
# Cosine Similarity Mean of B2 to A1 0.305
#
# Cosine Similarity STD of A2 to A1 0.119
# Cosine Similarity STD of B2 to B1 0.121
# Cosine Similarity STD of B2 to A1 0.14
# (-0.1, 1.2)

# %%
check_score_cluster('travel ban|travelban',.7)
# Out:
#    index  score tweet  index     score  \
# 0    NaN    NaN   NaN     10  0.660739
# 1    NaN    NaN   NaN     46  0.657359
#
#                                                tweet
# 0  as for trump's tweets about the travel ban, ev...
# 1  the only way the travel ban can "keep us safe"...

# %%
print('Event Tweets (earthquake): ', event_tweet_count('earthquake'))
A, B = tweets_event_ab_test('earthquake')
plt.scatter(range(len(A)), A, c = 'g')
plt.scatter(range(len(B)), B, c = 'r')
plt.ylim(-.1,1.2)
# Out:
# Event Tweets (earthquake):  1222
# A1|A2:  1.0
# B1|B2:  0.972
#
# A1|B1:  0.14
# A2|B2:  0.126
#
# Cosine Similarity Mean of A2 to A1 0.893
# Cosine Similarity Mean of B2 to B1 0.319
# Cosine Similarity Mean of B2 to A1 0.033
#
# Cosine Similarity STD of A2 to A1 0.199
# Cosine Similarity STD of B2 to B1 0.127
# Cosine Similarity STD of B2 to A1 0.113
# (-0.1, 1.2)

# %%
Top_scored_tweets_in_B('nbafinals', n = 300000)
# Out:
#            score  \
# 278091  0.776126
# 253084  0.772577
# 139447  0.772544
# 224011  0.767219
# 122257  0.764067
# 116215  0.762809
# 229050  0.758922
# 251115  0.758855
# 87633   0.756842
# 193301  0.756249
# 37495   0.754365
# 242425  0.751966
# 65158   0.751013
# 153715  0.750686
# 55614   0.750568
# 150302  0.750500
# 95022   0.750289
# 95912   0.749948
# 6641    0.749556
# 144777  0.748424
#
#                                                                                                                                                    tweet
# 278091  maybe the worst feeling ever is third wheeling &amp; the couple starts making out. that's like being the busted wheel on the train to bone zone.
# 253084  it's always the little things that convince you to keep going. cannot wait for these, even if the change is only on…
# 139447  hurry, hurry! deep blue see is coming! still time to read the first three in the series. the eyes have it on out of…
# 224011  the truest sense of peace that i've ever felt is when i'm strapped in and ready to go out on the track. (c) neil bo…
# 122257  11-0 run to end the game. choking a 7 point lead. yeah but let's hear some more 3-1 lead memes #brooms
# 116215  30 yrs ive been asking for the facts and nothing but the facts but this is the 1st time i ever seen someone claim v…
# 229050  go to the spurs &amp; the whole nba would get fucked up, spurs were shitting on warriors as it as already ... pg is the…
# 251115  news in the trump era is essentially each new hour telling the previous one to hold its beer.
# 87633   hey the time is now to just steamroll the #democrats and pass the #trump agenda. otherwise many of you will be voted out. believe it.
# 193301  trumps reading from the script but then emphasizes small phrases.. i think to help him understand the script better
# 37495    there is no doubt in this americans mind that trump stirred the conflict and through gasoline on it to increase the flame.
# 242425  or does a campaign being over make breaking the law acceptable?
# 65158   listening to karyn parsons sway interview &amp; its apparent that the 1st aunt viv is the only one who hates will smith lmfaoooo
# 153715  ricky reacting to logan paul &amp; the rock is the funniest thing i think i've ever seen 😂😂😂 i'm crying
# 55614   the only thing i hate about america is the terrorists who try to pass themselves off as christians and patriots but…
# 150302  exactly &amp; the worse part is they wasn't even born to watch mj play that's the mind boggling part
# 95022    well yeah the answer isn't hard to find but i think the article coulda been fun
# 95912    think there is legit truth to that. his id creates the "message", and the rest of the crew has to try…
# 6641    huge shout out to jeremy corbyn on defying the odds &amp; the people, especially young people who made the impossible..possible! #ge2017
# 144777  i note again that in a pride of lions, the oldest lion is king, and the immature younger male lions are banished to the bush, never to mate.

# %%
Top_scored_tweets_in_B('wonderwoman', n = 300000)
# Out:
#            score  \
# 135096  0.772777
# 28314   0.742511
# 293841  0.742482
# 45911   0.737561
# 232638  0.736616
# 279361  0.735394
# 283711  0.733617
# 206676  0.732223
# 101664  0.732109
# 59578   0.731991
# 170954  0.730532
# 170452  0.729634
# 87347   0.729503
# 182912  0.728764
# 59950   0.725888
# 63501   0.725674
# 210721  0.724452
# 237603  0.724025
# 148640  0.723829
# 156165  0.723285
#
#                                                                                                                                                    tweet
# 135096   movie is just wrong and was never the case. it took the discovery of ares for her to truly learn a…
# 28314   and you thought jason takes manhattan was weird. the kill count for jason goes to hell is here! watch &amp; subscribe!
# 293841  tonight the bomb is going to put on a very punk rock show for you. it's the first night of…
# 45911   i was going to rot in the dark in the comfort of my room but i guess people are coming over and it's going to be a long night
# 232638  #thekeepers is a worthy docuseries to watch and i hope it does something to help victims of sexual abuse &amp; the system that's in place today.
# 279361  my repair guy in la was out of the shop these last 2 days, so i fixed the flight damage to the bass myself. it's 90% where it should be 🤞
# 283711  this feels somewhat biased to be and when i look for some of the source info it is not there. however i respect the…
# 206676  the ❤️ is real! someone had brought him the food! "it was so good i had to find y'all and come…
# 101664  #ivebeenwaitingfor for a girl like you, to come into my life ...the last one quit and it's just so hard to find good help these days...
# 59578    volume one sounds so weird today but it was the jam back in 2012. and shouts to bebe rexha for hosting…
# 170954   it was super cool to see you yesterday! thanks for welcoming us and good luck with the rest of the run!
# 170452  lmfao this is so fucking frustrating :-)))) i hate doing something and finding out it didn't need to be done in the first place
# 87347   i was freaking out earlier bc they almost returned my package to the sender lmao fjsdfjdjf i ran to the post office and got it there t__t
# 182912  holy shit. i had the summer set jams in my car and randomly the tom cochrane version of life is. a highway cut it off to play.. dales how?!
# 59950   i've never been so hyped to watch two teams go at it, where one of them isn't the lakers. this series really is a gift.
# 63501    as someone who used php for a long time, it is pretty great though to see thats still the pattern of things. :)
# 210721  the weekend is (almost) here and it's time to relax. one hour of reflexology + body massage…
# 237603  told my gf to look up the movie time for wonder woman.. we go to the theaters.. found out it was to the 3d showingsmh she had one job
# 148640  to the rest of us sane human beings in the us who actually care about this planet, it's up to us now more than ever
# 156165  omfg the car washer found my black bralette in my car and i thought it was a rag &amp; i gave it to him and said i think this is yours but nope

# %%
Top_scored_tweets_in_B('travel Ban|travelban', n = 300000)

# %%
Top_scored_tweets_in_B('paris|climate', n = 300000)
