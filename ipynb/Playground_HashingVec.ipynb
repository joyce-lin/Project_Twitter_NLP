# %%
import requests
import numpy as np
import pandas as pd
import json
from IPython.display import display
import re
import os,sys,inspect
currentdir = os.path.dirname(os.path.abspath(inspect.getfile(inspect.currentframe())))
parentdir = os.path.dirname(currentdir)
sys.path.insert(0,parentdir)

from lib.twitter_keys import keys

# %%
sql_select = '''
select * from tweets where lang = 'en'
'''

# %%
import psycopg2 as pg2
import psycopg2.extras as pgex
this_host='54.69.228.16'
this_user='postgres'
this_password='postgres'
conn = pg2.connect(host = this_host, 
                        user = this_user,
                        password = this_password)
cur = conn.cursor(cursor_factory=pgex.RealDictCursor)
#cur.execute(sql_create)
#cur.execute(sql_drop)
#cur.execute(sql_insert)
#conn.commit()
cur.execute(sql_select)
rows = cur.fetchall()
conn.close()
df = pd.DataFrame(rows)

# %%
len(df)
# Out:
# 58902

# %%
df.tail(100)
# Out:
#                                            cleaned_tweet        country  \
# 58802  my theory behind the elite allowing a trump pr...  United States
# 58803           are these worth anything this week? lol   United States
# 58804  i 💕 they have everything and they're just over...  United States
# 58805       most people would call me a double at least   United States
# 58806                                sue bc it's illegal  United States
# 58807   why couldn't you sell out after my girls got ...  United States
# 58808                    you, sir, are a piece of shit.   United States
# 58809                                 just ordered mine   United States
# 58810  all i want in this life is to go to the cheese...  United States
# 58811       going live tonight what game should we play?  United States
# 58812                                 love, roald dahl.   United States
# 58813   he has some cold songs but i couldn't fuck wi...  United States
# 58814  join the wm team! see our latest opening here:...  United States
# 58815  join the lucile packard children’s hospit... t...  United States
# 58816                                           annoying  United States
# 58817  yelling @ steph dressed like a nigga first day...  United States
# 58818  when i work out now, it's less for the endorph...  United States
# 58819        love is what contain the soul of the pure.   United States
# 58820                  fuck it up fuck it up fuck it up   United States
# 58821                         looks like i'll die tryin   United States
# 58822                     one day all this gonna pay off  United States
# 58823  introducing...a capsule hotel 😱! it's like spa...  United States
# 58824  i forgot i changed my passcode to my phone las...  United States
# 58825                hope everyones day is going well ✨   United States
# 58826   im so confused. i thought that was in my noti...  United States
# 58827  instagram is the most harmful app for mental h...  United States
# 58828         summer is going to be so lit w/ my girls 😛  United States
# 58829  step 1: strip essential healthcare away from m...  United States
# 58830   think tanks like the heritage foundation, are...  United States
# 58831                cannot wait to try this at home 😍😋   United States
# ...                                                  ...            ...
# 58872  usgs reports a m1.02 17km ese of anza, ca on 6...  United States
# 58873  usgs reports a m1.02 17km ese of anza, ca on 6...  United States
# 58874  ya...like how to invade other countries with h...  United States
# 58875  *federal government wording here not by accide...  United States
# 58876                     i got my favorite right here:   United States
# 58877  shopping. restaurants. entertainment (@ westwo...  United States
# 58878                   i just wanna play sims right now  United States
# 58879                        you hoes be doing the extra  United States
# 58880  "dilemma" remix on our ever-so popular "vibrat...  United States
# 58881  i'm tired of magnet thinking that we could all...  United States
# 58882      want to work in ca? view our latest opening:   United States
# 58883                     "soul not for sale©" by 2017.   United States
# 58884           if she top, i'm in love, imma let it go.  United States
# 58885  what ❓usually 😂happens when you 👉 worry 😥...i ...  United States
# 58886  warriors - i picked the warriors, who do you s...  United States
# 58887   los angeles, san francisco, san diego, chicag...  United States
# 58888   yeah. well hopefully she cleans her shit up.....  United States
# 58809       city  None              0     False    BruceBranstad
# 58810      admin  None              0     False  jessssssssss___
# 58811       city  None              0     False   sirbojangleIII
# 58812       city  None              0     False          LoMayne
# 58813       city  None              0     False  BounceRoccSkate
# 58814       city  None              0     False   tmj_cao_transp
# 58815      admin  None              0     False          SCHJobs
# 58816       city  None              0     False       A_TizzleYo
# 58817       city  None              0     False   Scott_CEOofSUH
# 58818       city  None              0     False    AutumnChiklis
# 58819       city  None              0     False   kamalthefunman
# 58820       city  None              0     False      DavidBasley
# 58821       city  None              0     False       jenediaz11
# 58822      admin  None              0     False        billy_188
# 58823       city  None              0     False          CupofTJ
# 58824       city  None              0     False          anchxxr
# 58825       city  None              0     False    Dinoo_Monster
# 58826       city  None              0     False  gabrielapmendez
# 58827       city  None              0     False       DrDeniseMD
# 58828       city  None              0     False  _jazzzynicoleee
# 58829       city  None              0     False         sahluwal
# 58830      admin  None              0     False     markusgarvey
# 58831       city  None              0     False  loveme_ortiz_me
# ...          ...   ...            ...       ...              ...
# 58872      admin  None              0     False  everyEarthquake
# 58873      admin  None              0     False          SoCalEq
# 58874      admin  None              0     False      JardineKari
# 58875       city  None              0     False    vocaljavelins
# 58876       city  None              0     False  digitaldiatribe
# 58877       city  None              0     False           AHylen
# 58878       city  None              0     False    NCunningham88
# 58879       city  None              0     False  princesaaadesss
# 58880       city  None              0     False      ShoeFanatix
# 58881       city  None              0     False     katiehorrors
# 58882       city  None              0     False   tmj_lax_transp
# 58883      admin  None              0     False    BRAILLIANTArt
# 58884      admin  None              0     False   jaredchandlerr
# 58885       city  None              0     False  JoyceDa91450527
# 58886       city  None              0     False  holysoulmakave1
# 58887       city  None              0     False         jmichelo
# 58888       city  None              0     False    caffeinecholo
# 58889      admin  None              0     False  chrissy_linfoot
# 58890       city  None              0     False   BrendaaGaricaa
# 58891       city  None              0     False  RemembrancerBex
# 58892       city  None              0     False   BEWAREOFDANGER
# 58893       city  None              0     False   DSA_LosAngeles
# 58894       city  None              0     False   JulietHinojosa
# 58895       city  None              0     False          djinfo1
# 58896       city  None              0     False      KrissHussle
# 58897       city  None              0     False         onlangel
# 58898       city  None              0     False        porter321
# 58899       city  None              0     False      Maarcus_Uno
# 58900      admin  None              0     False  Foreverloved_95
# 58901        poi  None              0     False   mfbiancaakills
#
#                         time_zone  \
# 58802                        None
# 58803  pacific time (us & canada)
# 58804                       quito
# 58805  central time (us & canada)
# 58806  pacific time (us & canada)
# 58807  pacific time (us & canada)
# 58808  pacific time (us & canada)
# 58809                        None
# 58810                        None
# 58811  eastern time (us & canada)
# 58812  central time (us & canada)
# 58813  pacific time (us & canada)
# 58814  eastern time (us & canada)
# 58815                        None
# 58816                     arizona
# 58817  central time (us & canada)
# 58818  pacific time (us & canada)
# 58819                        None
# 58820                        None
# 58821                        None
# 58822                        None
# 58823                     arizona
# 58824                        None
# 58825                        None
# 58826  pacific time (us & canada)
# 58827  pacific time (us & canada)
# 58828  pacific time (us & canada)
# 58829                        None
# 58830  pacific time (us & canada)
# 58884           if she top, i'm in love, imma let it go.  None
# 58885  what ❓usually 😂happens when you 👉 worry 😥...i ...  None
# 58886  warriors - i picked the warriors, who do you s...  None
# 58887  @marty_walsh @realdonaldtrump los angeles, san...  None
# 58888  @lhnhff yeah.  well hopefully she cleans her s...  None
# 58889  1/3 emo twat  1/3 wannabe hood rat lil bitch 1...  None
# 58890                                 i'm about to cry .  None
# 58891  my parents live in south florida. you don't ne...  None
# 58892  delaja lifestyle 😍🇯🇲🇺🇸💜vision coming into real...  None
# 58893              keep dialing! https://t.co/je0zhdglzc  None
# 58894  i would love a relationship with someone as am...  None
# 58895  now the yung just are playing annoying to make...  None
# 58896  smokin dope lookin at a view over the beautifu...  None
# 58897  i can't wait to go to paris and caption everyo...  None
# 58898    i freaking ❤️ this guy👍 https://t.co/2xjgrbpqzq  None
# 58899           boy i'd go ham 😭 https://t.co/z8jfvo8au9  None
# 58900                               intelligence is sexy  None
# 58901                  currently https://t.co/6vw9kpjg5j  None
#
# [100 rows x 20 columns]

# %%
from sklearn.feature_extraction.text import HashingVectorizer

# %%
hv= HashingVectorizer(non_negative=True)

# %%
hv.partial_fit(df['tweet_content'])
# Out:
# HashingVectorizer(analyzer='word', binary=False, decode_error='strict',
#          dtype=<class 'numpy.float64'>, encoding='utf-8', input='content',
#          lowercase=True, n_features=1048576, ngram_range=(1, 1),
#          non_negative=True, norm='l2', preprocessor=None, stop_words=None,
#          strip_accents=None, token_pattern='(?u)\\b\\w\\w+\\b',
#          tokenizer=None)

# %%
hv.transform(df['tweet_content'])
# Out:
# <58902x1048576 sparse matrix of type '<class 'numpy.float64'>'
# 	with 713324 stored elements in Compressed Sparse Row format>

# %%
art_text_cvec = hv.transform(article_text)
art_text_vec = tsvd.transform(art_text_cvec)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-48-77a14f4df9aa> in <module>()
# ----> 1 art_text_cvec = hv.transform(article_text)
#       2 art_text_vec = tsvd.transform(art_text_cvec)
#
# NameError: name 'article_text' is not defined

# %%
import psycopg2 as pg2
import psycopg2.extras as pgex
this_host='54.69.228.16'
this_user='postgres'
this_password='postgres'
conn = pg2.connect(host = this_host, 
                        user = this_user,
                        password = this_password)
from sklearn.feature_extraction.text import HashingVectorizer
hv= HashingVectorizer(non_negative=True,stop_words='english')
count = 0
while count < 5000: 
    sql_select = '''
    select * from tweets_20170529 where lang = 'en' limit 1000 offset {}
    '''.format(count)
    count += 1000
    print(count)
    cur = conn.cursor(cursor_factory=pgex.RealDictCursor)
    cur.execute(sql_select)
    rows = cur.fetchall()
    df = pd.DataFrame(rows)
    hv.partial_fit(df['tweet_content'])
    
conn.close()    
print('done')
# Out:
# 1000
# 2000
# 3000
# 4000
# 5000
# done

# %%
tweets_hv = hv.transform(df['tweet_content'].values.astype('U'))

# %%
tweets_hv
# Out:
# <60538x1048576 sparse matrix of type '<class 'numpy.float64'>'
# 	with 447853 stored elements in Compressed Sparse Row format>

# %%
hv.transform([df['tweet_content'][0]]).shape
# Out:
# (1, 1048576)

# %%
from sklearn.feature_extraction.text import CountVectorizer
cv= CountVectorizer(stop_words='english')

# %%
import psycopg2.extras as pgex
this_host='54.69.228.16'
this_user='postgres'
this_password='postgres'
conn = pg2.connect(host = this_host, 
                        user = this_user,
                        password = this_password)
from sklearn.feature_extraction.text import CountVectorizer
cv= CountVectorizer(stop_words='english')
count = 0
while count < 100000: 
    sql_select = '''
    select * from tweets_20170529 where lang = 'en' limit 1000 offset {}
    '''.format(count)
    count += 1000
    print(count)
    cur = conn.cursor(cursor_factory=pgex.RealDictCursor)
    cur.execute(sql_select)
    rows = cur.fetchall()
    df = pd.DataFrame(rows)
    cv. partial_fit(df['tweet_content'])
conn.close()    
print('done')
# Out:
# 1000
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-11-25b87fc8daa0> in <module>()
#      19     rows = cur.fetchall()
#      20     df = pd.DataFrame(rows)
# ---> 21     cv.partial_fit(df['tweet_content'])
#      22 conn.close()
#      23 print('done')
#
# AttributeError: 'CountVectorizer' object has no attribute 'partial_fit'

# %%
from sklearn.linear_model import SGDClassifier
from sklearn.pipeline import Pipeline
from sklearn.feature_extraction.text import HashingVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.multiclass import OneVsRestClassifier

classifier = Pipeline([
    ('vectorizer', HashingVectorizer(ngram_range=(1,4), non_negative=True)),
    ('tfidf', TfidfTransformer()),
    ('clf', OneVsRestClassifier(SGDClassifier())),
])

# %%
def partial_pipe_fit(pipeline_obj, df):
    X = pipeline_obj.named_steps['mapper'].fit_transform(df)
    Y = df['class']
    pipeline_obj.named_steps['clf'].partial_fit(X,Y)

# %%
# !pip install sklearn-pandas
# Out:
# Collecting sklearn-pandas
#   Downloading sklearn_pandas-1.4.0-py2.py3-none-any.whl
# Requirement already satisfied (use --upgrade to upgrade): pandas>=0.11.0 in /opt/conda/lib/python3.5/site-packages (from sklearn-pandas)
# Requirement already satisfied (use --upgrade to upgrade): scipy>=0.14 in /opt/conda/lib/python3.5/site-packages (from sklearn-pandas)
# Requirement already satisfied (use --upgrade to upgrade): numpy>=1.6.1 in /opt/conda/lib/python3.5/site-packages (from sklearn-pandas)
# Requirement already satisfied (use --upgrade to upgrade): scikit-learn>=0.15.0 in /opt/conda/lib/python3.5/site-packages (from sklearn-pandas)
# Requirement already satisfied (use --upgrade to upgrade): python-dateutil>=2 in /opt/conda/lib/python3.5/site-packages (from pandas>=0.11.0->sklearn-pandas)
# Requirement already satisfied (use --upgrade to upgrade): pytz>=2011k in /opt/conda/lib/python3.5/site-packages (from pandas>=0.11.0->sklearn-pandas)
# Requirement already satisfied (use --upgrade to upgrade): six>=1.5 in /opt/conda/lib/python3.5/site-packages (from python-dateutil>=2->pandas>=0.11.0->sklearn-pandas)
# Installing collected packages: sklearn-pandas
# Successfully installed sklearn-pandas-1.4.0
# You are using pip version 8.1.2, however version 9.0.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
from sklearn_pandas import DataFrameMapper, cross_val_score
to_vect = Pipeline([('vect', CountVectorizer(min_df=2, max_df=.9, ngram_range=(1, 1), max_features = 100)),
                            ('tfidf', TfidfTransformer())])
full_mapper = DataFrameMapper([
            ('norm_text', to_vect),
            ('norm_fname', to_vect), ])

full_pipe = Pipeline([('mapper', full_mapper), ('clf', SGDClassifier(n_iter=15, warm_start=True,
                                                                n_jobs=-1, random_state=42))])

# %%
full_mapper
# Out:
# DataFrameMapper(default=False, df_out=False,
#         features=[('norm_text', Pipeline(steps=[('vect', CountVectorizer(analyzer='word', binary=False, decode_error='strict',
#         dtype=<class 'numpy.int64'>, encoding='utf-8', input='content',
#         lowercase=True, max_df=0.9, max_features=100, min_df=2,
#         ngram_range=(1, 1), preprocessor=None...), ('tfidf', TfidfTransformer(norm='l2', smooth_idf=True, sublinear_tf=False, use_idf=True))]), {})],
#         input_df=False, sparse=False)

# %%
DataFrameMapper
# Out:
# sklearn_pandas.dataframe_mapper.DataFrameMapper
